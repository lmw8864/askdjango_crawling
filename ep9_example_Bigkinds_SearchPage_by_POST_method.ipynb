# %% [markdown]
# # 크롤링 실습 - POST 방식으로 검색을 구현한 페이지에 대한 분석
# - [빅카인즈](http://211.43.216.33/search/totalSearchMain.do) 에서 '문재인' 검색 페이지 분석/크롤링
# - **POST 방식** 검색 페이지
# - 키워드를 검색하면 get인자로 데이터를 넘겨주는 방식이 아니라서 **주소가 변하지 않음**.
#
# ## _How to?_
# 1. 개발자 도구 > Network 탭에서 Form Data 내용을 복사해와서 사전 데이터로 만들기 (전처리)
# 2. 요청(Request)할 때 사전으로 만든 데이터를 함께 전달하면, 그에 대한 응답(Response)를 받을 수 있다.
# 3. 응답으로 받은 html을 파싱

# %% [markdown]
# ## 1. 전체 코드

# %% [markdown]
# ## 2. 한 단계씩 보기

# %% [markdown]
# ### 개발자 도구 > Network 탭에서 Form Data 를 가져와서 사전 데이터로 만들기 (전처리)

# %% [raw]
# # Form Data
#
# keyword:문재인
# popKeyword:
# realKeyword:
# keywordType:N
# fieldRadio:_search
# search_field:_search
# byline:
# methodRadio:0
# search_method:0
# fromDate:
# toDate:
# provider_code:
# provider_name:
# category_code:
# category_name:
# larm_incident_category_path:
# larm_incident_category_nm:

# %%
lines = '''keyword:문재인
popKeyword:
realKeyword:
keywordType:N
fieldRadio:_search
search_field:_search
byline:
methodRadio:0
search_method:0
fromDate:
toDate:
provider_code:
provider_name:
category_code:
category_name:
larm_incident_category_path:
larm_incident_category_nm:'''.splitlines()  # 줄 단위로 쪼개기

lines
# Out:
# ['keyword:문재인',
#  'popKeyword:',
#  'realKeyword:',
#  'keywordType:N',
#  'fieldRadio:_search',
#  'search_field:_search',
#  'byline:',
#  'methodRadio:0',
#  'search_method:0',
#  'fromDate:',
#  'toDate:',
#  'provider_code:',
#  'provider_name:',
#  'category_code:',
#  'category_name:',
#  'larm_incident_category_path:',
#  'larm_incident_category_nm:']

# %%
data = {}

for line in lines:
    key, value = line.split(':', 1)  # 콜론(:) 한 개로 구분
    if value == 'null':
        value = None
    print(key, value)
    data[key] = value

data
# Out:
# keyword 문재인
# popKeyword
# realKeyword
# keywordType N
# fieldRadio _search
# search_field _search
# byline
# methodRadio 0
# search_method 0
# fromDate
# toDate
# provider_code
# provider_name
# category_code
# category_name
# larm_incident_category_path
# larm_incident_category_nm
# {'byline': '',
#  'category_code': '',
#  'category_name': '',
#  'fieldRadio': '_search',
#  'fromDate': '',
#  'keyword': '문재인',
#  'keywordType': 'N',
#  'larm_incident_category_nm': '',
#  'larm_incident_category_path': '',
#  'methodRadio': '0',
#  'popKeyword': '',
#  'provider_code': '',
#  'provider_name': '',
#  'realKeyword': '',
#  'search_field': '_search',
#  'search_method': '0',
#  'toDate': ''}

# %%
str.split?

# %% [markdown]
# ### 사전 데이터를 실어서 요청 -> 응답받기

# %%
import requests
from bs4 import BeautifulSoup

# %%
result_url = 'http://211.43.216.33/search/totalSearchList.do'

response = requests.post(result_url, data=data)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\r\n\r\n\r\n\r\n<html lang="ko">\r\n\t<head>\r\n\t\t<meta charset="utf-8">\r\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n\t\t<meta name="description" content="뉴스빅데이터 분석시스템, 뉴스 속 키워드 관계망, 주요 이슈, 정보원, 이슈 트렌드 분석 정보 제공">\r\n\t\t<meta name="keywords" content="BIG KINDS, big kinds, 빅카인즈, 빅 카인즈, 카인즈, kinds, Kinds">\r\n\t\t<meta property="og:type" content="website">\r\n\t\t<meta property="og:title" content="BIG KINDS">\r\n\t\t<meta property="og:description" content="뉴스빅데이터 분석시스템, 뉴스 속 키워드 관계망, 주요 이슈, 정보원, 이슈 트렌드 분석 정보 제공">\r\n\t\t<meta property="og:url" content="http://www.bigkinds.or.kr">\r\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=yes">\r\n\t\t<title>BIG KINDS | 통합 검색 기사</title>\r\n\t\t<link rel="canonical" href="http://www.bigkinds.or.kr/">\r\n\t\t<link rel="stylesheet" href="http://fonts.googleapis.com/earlyaccess/nanumgothic.css">\r\n\t\t<link rel="stylesheet" type="text/css" href="/webcont/css/kpf.css">\r\n\t\t<script src="/webcont/js/modernizr-1.7.min.js"></script>\r\n\t\t<!-- <script src="http://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js"></script> -->\r\n\t\t<script type="text/javascript" src="/webcont/js/jquery-1.9.1.googleapis.min.js"></script>\r\n\t\t<script>window.jQuery || document.write("<script src=\'/webcont/js/jquery-1.7.1.min.js\'>\\x3C/script>")</script>\r\n\t\t<script type="text/javascript" src="/webcont/js/uncompressed.jquery.dd.js"></script>\r\n\t\t<script type="text/javascript" src="/webcont/js/jquery.popup.js?20160429"></script>\r\n\t\t<!-- <script type="text/javascript" src="/webcont/js/d3.js"></script> -->\r\n\t\t<script type="text/javascript" src="/webcont/js/d3.3.4.9.js"></script>\r\n\t\t<script type="text/javascript" src="/webcont/js/common.js?20160429"></script>\r\n\t\t<script type="text/javascript" src="/webcont/js/wordcloud.js"></script>\r\n\t\t<script type="text/javascript" src="/webcont/js/jquery-ui.min.js"></script>\r\n\t\t<link type="text/css" href="http://code.jquery.com/ui/1.10.3/themes/smoothness/jquery-ui.css" rel="stylesheet">\r\n\t\t<script type="text/javascript" src="/webcont/js/ui.datepicker-ko.js"></script>\r\n\t\t<!--[if lt IE 9]>\r\n  \t\t\t<script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>\r\n\t\t<![endif]-->\r\n\t</head>\r\n\r\n\t<body>\r\n\r\n\t\t<!--S: skip navi -->\r\n\t\t<div id="skipnav">\r\n\t\t\t<ul>\r\n\t\t\t\t<li><a href="#document_skip">본문 바로가기</a></li>\r\n\t\t\t\t<li><a href="#nav_skip">주 메뉴 바로가기</a></li>\r\n\t\t\t</ul>\r\n\t\t</div>\r\n\t\t<!--E: skip navi -->\r\n\r\n\t\t<!--S: wrapper -->\r\n\t\t<div id="wrapper">\r\n\t\t\t\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<script type="text/javascript" src="/webcont/js/autoComplete.js"></script>\r\n<script type="text/javascript" src="/webcont/js/jquery.cookie.js"></script>\r\n<script type="text/javascript" src="/webcont/js/jquery.highlight-4.js"></script>\r\n\r\n<script src="/webcont/js/tree/jstree.js" type="text/javascript"></script>\r\n<link rel="stylesheet" href="/webcont/js/tree/skin/treeStyle.css" />\r\n\r\n<style>\r\n.highlight {background-color:yellow;}\r\n</style>\r\n\r\n<input type="hidden" id="login_chk" value="null"/>\r\n<input type="hidden" id="user_id" value="null"/>\r\n\r\n<!--S: header -->\r\n<div id="header">\r\n\t<div class="topwrap">\r\n\t\t<ul class="topmenu">\r\n\t\t\t\r\n\t\t\t\t\r\n\t\t\t\t\r\n\t\t\t\t\t<!-- <li><a href="#" onclick="fn_movePage(\'L\');">로그인</a></li> -->\r\n\t\t\t\t\t<!-- <li><a href="http://www.kpf.or.kr/auth/new_ageconfirm.do" target="_blank">회원가입</a></li> -->\r\n\t\t\t\t\r\n\t\t\t\r\n\t\t\t<!-- <li><a href="#">로그인</a></li> -->\r\n\t\t\t<li><a href="/help/helpFaqList.do">고객센터</a></li>\r\n\t\t\t<li><a href="/help/helpSiteMap.do">사이트맵</a></li>\r\n\t\t</ul>\r\n\t</div>\r\n\t<div class="logoSearch">\r\n\t\t<h1><a href="/"><img src="/webcont/images/logo_top.png" alt="BIG KINDS 로고" class="logotop" /></a></h1>\r\n\r\n\t\t<div id="totalSearch">\r\n\t\ ...

# %% [markdown]
# ### 응답으로 받은 html 파싱

# %%
html = response.text
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="뉴스빅데이터 분석시스템, 뉴스 속 키워드 관계망, 주요 이슈, 정보원, 이슈 트렌드 분석 정보 제공" name="description"/>
# <meta content="BIG KINDS, big kinds, 빅카인즈, 빅 카인즈, 카인즈, kinds, Kinds" name="keywords"/>
# <meta content="website" property="og:type"/>
# <meta content="BIG KINDS" property="og:title"/>
# <meta content="뉴스빅데이터 분석시스템, 뉴스 속 키워드 관계망, 주요 이슈, 정보원, 이슈 트렌드 분석 정보 제공" property="og:description"/>
# <meta content="http://www.bigkinds.or.kr" property="og:url"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=yes" name="viewport"/>
# <title>BIG KINDS | 통합 검색 기사</title>
# <link href="http://www.bigkinds.or.kr/" rel="canonical"/>
# <link href="http://fonts.googleapis.com/earlyaccess/nanumgothic.css" rel="stylesheet"/>
# <link href="/webcont/css/kpf.css" rel="stylesheet" type="text/css"/>
# <script src="/webcont/js/modernizr-1.7.min.js"></script>
# <!-- <script src="http://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js"></script> -->
# <script src="/webcont/js/jquery-1.9.1.googleapis.min.js" type="text/javascript"></script>
# <script>window.jQuery || document.write("<script src='/webcont/js/jquery-1.7.1.min.js'>\x3C/script>")</script>
# <script src="/webcont/js/uncompressed.jquery.dd.js" type="text/javascript"></script>
# <script src="/webcont/js/jquery.popup.js?20160429" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="/webcont/js/d3.js"></script> -->
# <script src="/webcont/js/d3.3.4.9.js" type="text/javascript"></script>
# <script src="/webcont/js/common.js?20160429" type="text/javascript"></script>
# <script src="/webcont/js/wordcloud.js" type="text/javascript"></script>
# <script src="/webcont/js/jquery-ui.min.js" type="text/javascript"></script>
# <link href="http://code.jquery.com/ui/1.10.3/themes/smoothness/jquery-ui.css" rel="stylesheet" type="text/css"/>
# <script src="/webcont/js/ui.datepicker-ko.js" type="text/javascript"></script>
# <!--[if lt IE 9]>
#   			<script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>
# 		<![endif]-->
# </head>
# <body>
# <!--S: skip navi -->
# <div id="skipnav">
# <ul>
# <li><a href="#document_skip">본문 바로가기</a></li>
# <li><a href="#nav_skip">주 메뉴 바로가기</a></li>
# </ul>
# </div>
# <!--E: skip navi -->
# <!--S: wrapper -->
# <div id="wrapper">
# <script src="/webcont/js/autoComplete.js" type="text/javascript"></script>
# <script src="/webcont/js/jquery.cookie.js" type="text/javascript"></script>
# <script src="/webcont/js/jquery.highlight-4.js" type="text/javascript"></script>
# <script src="/webcont/js/tree/jstree.js" type="text/javascript"></script>
# <link href="/webcont/js/tree/skin/treeStyle.css" rel="stylesheet">
# <style>
# .highlight {background-color:yellow;}
# </style>
# <input id="login_chk" type="hidden" value="null"/>
# <input id="user_id" type="hidden" value="null"/>
# <!--S: header -->
# <div id="header">
# <div class="topwrap">
# <ul class="topmenu">
# <!-- <li><a href="#" onclick="fn_movePage('L');">로그인</a></li> -->
# <!-- <li><a href="http://www.kpf.or.kr/auth/new_ageconfirm.do" target="_blank">회원가입</a></li> -->
# <!-- <li><a href="#">로그인</a></li> -->
# <li><a href="/help/helpFaqList.do">고객센터</a></li>
# <li><a href="/help/helpSiteMap.do">사이트맵</a></li>
# </ul>
# </div>
# <div class="logoSearch">
# <h1><a href="/"><img alt="BIG KINDS 로고" class="logotop" src="/webcont/images/logo_top.png"/></a></h1>
# <div id="totalSearch">
# <form action="" id="topSearchForm" method="post" name="topSearchForm" onsubmit="return false;">
# <fieldset>
# <legend>통합검색</legend>
# <label class="blind" for="searchTotal">검색어</label>
# <!-- 검색어 입력시 font-size:0 으로 해 주세요-->
# <input autocomplete="off" class="text" id="searchTotal" name="keyword" onclick="fn_viewWordBox();" onkeyup="fn_autoComplete(this.value, event);" title="검색어 입력" type="text" value="문재인"/>
# <!-- class="arrUp" 접기-->
# <!-- <span class="icon arrDown" alt="펼침 버튼">펼치기</span> -->
# <!-- 검색버튼-->
# <!-- <input type="image" class="image" src="/webcont/images/btn/bu_searchbu.gif" alt="검색버튼" onclick="fn_search();" /> -->
# <a class="image" href="javascript:fn_search('Y');"><img alt="검색버튼" src="/webcont/images/btn/bu_searchbu.gif" width="37"/></a>
# <!-- 자동검색 영역 -->
# <!-- 레이어 :상세검색 자동검색어 -->
# <div alt="상세검색 자동검색어" class="autoWordMain" id="autoWordMain" style="display:none">
# <div class="autolist recent on"><!--탭제어 class="on"--->
# <p alt="" class="tabMenu"><a href="javascript:fn_showWordlist('1');">최근검색어</a></p>
# <ul class="autoR">
# </ul>
# </div>
# <div class="autolist favorite">
# <p alt="" class="tabMenu"><!-- <a href="javascript:fn_showWordlist('2');">관심 검색어</a> --></p>
# <ul class="autoF">
# </ul>
# </div>
# <div class="bu autoMenu">
# <a class="fl" href="javascript:fn_deleteRkeyword();">최근검색어목록삭제</a>
# <a class="keywordAuto" href="javascript:fn_autoYN();">자동완성 끄기</a><span class="bar1">|</span>
# <a class="keywordSave" href="javascript:fn_saveYN();">검색어저장 끄기</a>
# </div>
# <div class="bu favoriteMenu" style="display:none">
# <a class="srchWrdEdit" href="/personal/personalKeywordList.do">관심검색어관리</a>
# </div>
# <div class="bu favoriteMenuLogin" style="display:none">
# <a class="srchWrdEdit" href="/member/loginPage.do">로그인</a>
# </div>
# </div>
# <!--//자동검색어--->
# <!-- 자동완성 -->
# <!--레이어 :상세검색 자동검색어--->
# <div alt="상세검색 자동검색어" class="autoWordMain" id="autoKeywordDiv" style="display:none">
# <div class="autolist on"><!--탭제어 class="on"--->
# <p alt="" class="tabMenu"><a href="">검색어 자동완성</a></p>
# <ul class="autoC"></ul>
# </div>
# <div class="bu">
# <a class="keywordAuto" href="javascript:fn_autoYN();">자동완성 끄기</a><span class="bar1">|</span>
# <a class="keywordSave" href="javascript:fn_saveYN();">검색어저장 끄기</a></div>
# </div>
# <!--// 자동검색어 -->
# </fieldset>
# <div class="keyword">
# <h3>인기검색어</h3>
# <ul class="popularSearchWord"></ul>
# </div>
# <div class="modal w700" id="popupLayer1" style="display:none">
# <div class="popLayerWrap">
# <header class="popLayerHeader">
# <h1 class="popLayerTitle">상세검색</h1>
# <input alt="팝업닫기" class="btnLayerClose close1" src="/webcont/images/btn/btn_close.gif" type="image"/>
# </header>
# <div class="popLayerContent">
# <!-- 조건 -->
# <div class="boardWrite pop">
# <table>
# <caption>상세검색옵션</caption>
# <colgroup>
# <col style="width:90px"/>
# <col style="width:70px"/>
# <col style="width:*">
# <col style="width:90px"/>
# <col style="width:240px">
# </col></col></colgroup>
# <tbody>
# <tr>
# <th>검색어</th>
# <td colspan="4">
# <input autocomplete="off" class="w96p" id="popKeyword" name="popKeyword" placeholder="검색어" type="text" value=""/>
# <label class="blind" for="popKeyword">검색어</label>
# <input class="w80p" id="realKeyword" name="realKeyword" type="hidden"/>
# <label class="blind" for="realKeyword">실제검색어</label>
# <input class="w10p" id="keywordType" name="keywordType" type="hidden" value="N"/>
# <label class="blind" for="keywordType">검색어타입</label>
# </td>
# </tr>
# <tr>
# <th>검색범위선택</th>
# <td colspan="2">
# <input checked="" id="field01" name="fieldRadio" onclick="clickField();" type="radio" value="_search"/>전체
# 								<label class="blind" for="field01">전체</label>
# <input id="field02" name="fieldRadio" onclick="clickField();" type="radio" value="title"/>제목
# 								<label class="blind" for="field02">제목</label>
# <input id="field03" name="fieldRadio" onclick="clickField();" type="radio" value="content"/>본문
# 								<label class="blind" for="field03">본문</label>
# <input id="search_field" name="search_field" type="hidden" value="_search">
# </input></td>
# <th>기고자</th>
# <td>
# <input class="w80p" id="byline" name="byline" placeholder="기고자" type="text">
# </input></td>
# </tr>
# <tr>
# <th>검색방식선택</th>
# <td colspan="4">
# <input checked="" id="method01" name="methodRadio" onclick="clickMethod();" type="radio" value="0"/>형태소 분석
# 								<label class="blind" for="method01">형태소 분석</label>
# <input id="method02" name="methodRadio" onclick="clickMethod();" type="radio" value="1"/>바이그램
# 								<label class="blind" for="method02">바이그램</label>
# <input id="method03" name="methodRadio" onclick="clickMethod();" type="radio" value="2"/>바이그램 + 형태소 분석
# 								<label class="blind" for="method03">바이그램 + 형태소 분석</label>
# <input id="search_method" name="search_method" type="hidden" value="0">
# </input></td>
# </tr>
# <tr>
# <th>기간선택</th>
# <td colspan="4">
# <div class="mb7 txt_oran">* 직접 입력시, "20150101" 형식으로 넣어주세요. </div>
# <div class="searchGroup">
# <label class="blind" for="fromDate">검색기간 시작일 날짜선택</label>
# <input alt="날짜입력" autocomplete="off" class="input_date onlyNum" id="fromDate" maxlength="8" name="fromDate" onkeypress="InputOnlyNumber(this);" onkeyup="this.value=this.value.replace(/[^0-9]/g,'')" type="text" value=""/>
# <!-- <a href="#"><img class="bu_cal" alt="날짜선택" src="/webcont/images/btn/bu_calender.gif"></a> --><b class="bar1">~</b>
# <label class="blind" for="toDate">검색기간 종료일 날짜선택</label>
# <input alt="날짜입력" autocomplete="off" class="input_date onlyNum" id="toDate" maxlength="8" name="toDate" onkeypress="InputOnlyNumber(this);" onkeyup="this.value=this.value.replace(/[^0-9]/g,'')" type="text" value=""/>
# <!-- <a href="#"><img class="bu_cal" alt="날짜선택" src="/webcont/images/btn/bu_calender.gif"></a> -->
# <span class="lineL" id="lineL">
# <span class="buIcon btnTab"><input alt="검색기간 전체" onclick="setDate(0);" type="button" value="전체"/></span>
# <span class="buIcon btnTab"><input alt="검색기간 오늘" onclick="setDate(1);" type="button" value="오늘"/></span>
# <span class="buIcon btnTab"><input alt="검색기간 1주일 버튼" onclick="setDate(7);" type="button" value="1주"/></span>
# <span class="buIcon btnTab"><input alt="검색기간 1개월 버튼" onclick="setDate(30);" type="button" value="1개월"/></span>
# <span class="buIcon btnTab"><input alt="검색기간 1년 버튼" onclick="setDate(365);" type="button" value="1년"/></span>
# </span>
# </div>
# </td>
# </tr>
# <tr class="none">
# <th>언론사선택</th>
# <td colspan="4">
# <select class="w150" id="mediaCodeCombo" onchange="changeProvider();">
# <option value="">매체종류를 선택하세요</option>
# <option value="01">종합일간지</option>
# <option value="02">경제일간지</option>
# <option value="03">영자일간지</option>
# <option value="04">인터넷신문</option>
# <option value="05">지역신문</option>
# <option value="06">시사잡지</option>
# <option value="07">전문신문</option>
# <option value="08">방송</option>
# <option value="09">통신사</option>
# <option value="10">스포츠신문</option>
# <option value="11">잡지</option>
# </select>
# <label class="blind" for="mediaCodeCombo">매체종류선택</label>
# <select class="w150 ml5" id="areaCodeCombo" onchange="changeProvider();">
# <option value="">지역구분을 선택하세요</option>
# <option value="10">서울</option>
# <option value="20">경기</option>
# <option value="30">강원</option>
# <option value="40">충청</option>
# <option value="41">충북</option>
# <option value="42">충남</option>
# <option value="50">경상</option>
# <option value="51">경북</option>
# <option value="52">경남</option>
# <option value="60">전라</option>
# <option value="61">전북</option>
# <option value="62">전남</option>
# <option value="70">제주</option>
# <option value="90">미국</option>
# <option value="91">중국</option>
# <option value="92">일본</option>
# </select>
# <label class="blind" for="areaCodeCombo">매체지역선택</label>
# <select class="w140 ml5" id="providerCodeCombo">
# <option value="0">언론사를 선택하세요</option>
# <option value="90100107">BBC</option>
# <option value="90100104">CNN</option>
# <option value="90300105">JAPAN Times</option>
# <option value="90100103">LA타임스</option>
# <option value="90300106">Nikkei asia</option>
# <option value="90100105">REUTERS</option>
# <option value="01300101">강원도민일보</option>
# <option value="01200101">경기일보</option>
# <option value="01500151">경남도민일보</option>
# <option value="01500051">경남신문</option>
# <option value="01500301">경상일보</option>
# <option value="01200201">경인일보</option>
# <option value="01100101">경향신문</option>
# <option value="01600301">광주일보</option>
# <option value="01100201">국민일보</option>
# <option value="01500401">국제신문</option>
# <option value="90200102">글로벌타임즈</option>
# <option value="01100301">내일신문</option>
# <option value="90100101">뉴욕타임스</option>
# <option value="01500501">대구일보</option>
# <option value="01400201">대전일보</option>
# <option value="07101201">디지털타임스</option>
# <option value="90300101">마이니치신문</option>
# <option value="02100101">매일경제</option>
# <option value="01500601">매일신문</option>
# <option value="01600501">무등일보</option>
# <option value="01100501">문화일보</option>
# <option value="01500701">부산일보</option>
# <option value="90300104">산케이신문</option>
# <option value="02100311">서울경제</option>
# <option value="01100611">서울신문</option>
# <option value="01100701">세계일보</option>
# <option value="90200101">신화통신</option>
# <option value="90300103">아사히신문</option>
# <option value="01500801">영남일보</option>
# <option value="90300102">요미우리신문</option>
# <option value="01500901">울산매일</option>
# <option value="90100102">워싱턴포스트</option>
# <option value="90100106">월스트리트저널</option>
# <option value="90200104">인민일보</option>
# <option value="01600801">전남일보</option>
# <option value="01601001">전북도민일보</option>
# <option value="01601101">전북일보</option>
# <option value="07100501">전자신문</option>
# <option value="01700101">제민일보</option>
# <option value="01400351">중도일보</option>
# <option value="01400401">중부매일</option>
# <option value="90200103">차이나데일리</option>
# <option value="01400551">충북일보</option>
# <option value="01400601">충청일보</option>
# <option value="01400701">충청투데이</option>
# <option value="02100501">파이낸셜뉴스</option>
# <option value="01101001">한겨레</option>
# <option value="02100601">한국경제</option>
# <option value="01101101">한국일보</option>
# <option value="01700201">한라일보</option>
# <option value="02100701">헤럴드경제</option>
# <option value="08100201">MBC</option>
# <option value="08200101">OBS</option>
# <option value="08100301">SBS</option>
# <option value="08100401">YTN</option>
# </select>
# <label class="blind" for="providerCodeCombo">매체선택</label>
# <select id="providerNameCombo" style="display:none;">
# <option value="90100107">BBC</option>
# <option value="90100104">CNN</option>
# <option value="90300105">JAPAN Times</option>
# <option value="90100103">LA타임스</option>
# <option value="90300106">Nikkei asia</option>
# <option value="90100105">REUTERS</option>
# <option value="01300101">강원도민일보</option>
# <option value="01200101">경기일보</option>
# <option value="01500151">경남도민일보</option>
# <option value="01500051">경남신문</option>
# <option value="01500301">경상일보</option>
# <option value="01200201">경인일보</option>
# <option value="01100101">경향신문</option>
# <option value="01600301">광주일보</option>
# <option value="01100201">국민일보</option>
# <option value="01500401">국제신문</option>
# <option value="90200102">글로벌타임즈</option>
# <option value="01100301">내일신문</option>
# <option value="90100101">뉴욕타임스</option>
# <option value="01500501">대구일보</option>
# <option value="01400201">대전일보</option>
# <option value="07101201">디지털타임스</option>
# <option value="90300101">마이니치신문</option>
# <option value="02100101">매일경제</option>
# <option value="01500601">매일신문</option>
# <option value="01600501">무등일보</option>
# <option value="01100501">문화일보</option>
# <option value="01500701">부산일보</option>
# <option value="90300104">산케이신문</option>
# <option value="02100311">서울경제</option>
# <option value="01100611">서울신문</option>
# <option value="01100701">세계일보</option>
# <option value="90200101">신화통신</option>
# <option value="90300103">아사히신문</option>
# <option value="01500801">영남일보</option>
# <option value="90300102">요미우리신문</option>
# <option value="01500901">울산매일</option>
# <option value="90100102">워싱턴포스트</option>
# <option value="90100106">월스트리트저널</option>
# <option value="90200104">인민일보</option>
# <option value="01600801">전남일보</option>
# <option value="01601001">전북도민일보</option>
# <option value="01601101">전북일보</option>
# <option value="07100501">전자신문</option>
# <option value="01700101">제민일보</option>
# <option value="01400351">중도일보</option>
# <option value="01400401">중부매일</option>
# <option value="90200103">차이나데일리</option>
# <option value="01400551">충북일보</option>
# <option value="01400601">충청일보</option>
# <option value="01400701">충청투데이</option>
# <option value="02100501">파이낸셜뉴스</option>
# <option value="01101001">한겨레</option>
# <option value="02100601">한국경제</option>
# <option value="01101101">한국일보</option>
# <option value="01700201">한라일보</option>
# <option value="02100701">헤럴드경제</option>
# <option value="08100201">MBC</option>
# <option value="08200101">OBS</option>
# <option value="08100301">SBS</option>
# <option value="08100401">YTN</option>
# </select>
# <input id="providerCode" name="provider_code" type="hidden" value="">
# <input id="providerName" name="provider_name" type="hidden" value="">
# <span class="buIcon btnTab mlr5">
# <input alt="분류추가" onclick="fn_add();" type="button" value="+ 추가"/>
# </span>
# <a href="javascript:fn_categoryInfo(1);">
# <img alt="기사 분류정보 보기(언론사선택)" class="middle" src="/webcont/images/btn/bu_quest.png" title="기사 분류정보 보기 새창열림">
# </img></a>
# <ul class="listLidot mt10" id="proName">
# </ul>
# </input></input></td>
# </tr>
# </tbody></table></div></div></div></div></form></div></div></div></link></div></body></html>
# <tr>
# <th rowspan="9">언론사선택</th>
# <th>
# <input id="localCheck10" name="localCheck" onclick="setLocalProvider(10, this);" type="checkbox"/>
# <label for="localCheck10">중앙지</label>
# </th>
# <td colspan="3">
# <ul class="li_dan5">
# <li>
# <input class="local10" id="mp01100101" name="main_provider" type="checkbox" value="01100101"/>
# <label class="mp01100101" for="mp01100101">경향신문</label>
# </li>
# <li>
# <input class="local10" id="mp01100201" name="main_provider" type="checkbox" value="01100201"/>
# <label class="mp01100201" for="mp01100201">국민일보</label>
# </li>
# <li>
# <input class="local10" id="mp01100301" name="main_provider" type="checkbox" value="01100301"/>
# <label class="mp01100301" for="mp01100301">내일신문</label>
# </li>
# <li>
# <input class="local10" id="mp01100501" name="main_provider" type="checkbox" value="01100501"/>
# <label class="mp01100501" for="mp01100501">문화일보</label>
# </li>
# <li>
# <input class="local10" id="mp01100611" name="main_provider" type="checkbox" value="01100611"/>
# <label class="mp01100611" for="mp01100611">서울신문</label>
# </li>
# <li>
# <input class="local10" id="mp01100701" name="main_provider" type="checkbox" value="01100701"/>
# <label class="mp01100701" for="mp01100701">세계일보</label>
# </li>
# <li>
# <input class="local10" id="mp01101001" name="main_provider" type="checkbox" value="01101001"/>
# <label class="mp01101001" for="mp01101001">한겨레</label>
# </li>
# <li>
# <input class="local10" id="mp01101101" name="main_provider" type="checkbox" value="01101101"/>
# <label class="mp01101101" for="mp01101101">한국일보</label>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>
# <input id="localCheck10" name="localCheck" onclick="setLocalProvider(12, this);" type="checkbox"/>
# <label for="localCheck10">경제지</label>
# </th>
# <td colspan="3">
# <ul class="li_dan5">
# <li>
# <input class="local12" id="mp02100101" name="main_provider" type="checkbox" value="02100101"/>
# <label class="mp02100101" for="mp02100101">매일경제</label>
# </li>
# <li>
# <input class="local12" id="mp02100311" name="main_provider" type="checkbox" value="02100311"/>
# <label class="mp02100311" for="mp02100311">서울경제</label>
# </li>
# <li>
# <input class="local12" id="mp02100501" name="main_provider" type="checkbox" value="02100501"/>
# <label class="mp02100501" for="mp02100501">파이낸셜뉴스</label>
# </li>
# <li>
# <input class="local12" id="mp02100601" name="main_provider" type="checkbox" value="02100601"/>
# <label class="mp02100601" for="mp02100601">한국경제</label>
# </li>
# <li>
# <input class="local12" id="mp02100701" name="main_provider" type="checkbox" value="02100701"/>
# <label class="mp02100701" for="mp02100701">헤럴드경제</label>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>
# <input id="localCheck20" name="localCheck" onclick="setLocalProvider(20, this);" type="checkbox"/>
# <label for="localCheck20"><b>경기</b></label>
# </th>
# <td colspan="3">
# <ul class="li_dan5">
# <li>
# <input class="local20" id="mp01200101" name="main_provider" type="checkbox" value="01200101"/>
# <label class="mp01200101" for="mp01200101">경기일보</label>
# </li>
# <li>
# <input class="local20" id="mp01200201" name="main_provider" type="checkbox" value="01200201"/>
# <label class="mp01200201" for="mp01200201">경인일보</label>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>
# <input id="localCheck30" name="localCheck" onclick="setLocalProvider(30, this);" type="checkbox"/>
# <label for="localCheck30"><b>강원</b></label>
# </th>
# <td colspan="3">
# <ul class="li_dan5">
# <li>
# <input class="local30" id="mp01300101" name="main_provider" type="checkbox" value="01300101"/>
# <label class="mp01300101" for="mp01300101">강원도민일보</label>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>
# <input id="localCheck40" name="localCheck" onclick="setLocalProvider(40, this);" type="checkbox"/>
# <label for="localCheck40"><b>충청</b></label>
# </th>
# <td colspan="3">
# <ul class="li_dan5">
# <li>
# <input class="local40" id="mp01400201" name="main_provider" type="checkbox" value="01400201"/>
# <label class="mp01400201" for="mp01400201">대전일보</label>
# </li>
# <li>
# <input class="local40" id="mp01400351" name="main_provider" type="checkbox" value="01400351"/>
# <label class="mp01400351" for="mp01400351">중도일보</label>
# </li>
# <li>
# <input class="local40" id="mp01400401" name="main_provider" type="checkbox" value="01400401"/>
# <label class="mp01400401" for="mp01400401">중부매일</label>
# </li>
# <li>
# <input class="local40" id="mp01400551" name="main_provider" type="checkbox" value="01400551"/>
# <label class="mp01400551" for="mp01400551">충북일보</label>
# </li>
# <li>
# <input class="local40" id="mp01400601" name="main_provider" type="checkbox" value="01400601"/>
# <label class="mp01400601" for="mp01400601">충청일보</label>
# </li>
# <li>
# <input class="local40" id="mp01400701" name="main_provider" type="checkbox" value="01400701"/>
# <label class="mp01400701" for="mp01400701">충청투데이</label>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>
# <input id="localCheck50" name="localCheck" onclick="setLocalProvider(50, this);" type="checkbox"/>
# <label for="localCheck50"><b>경상</b></label>
# </th>
# <td colspan="3">
# <ul class="li_dan5">
# <li>
# <input class="local50" id="mp01500151" name="main_provider" type="checkbox" value="01500151"/>
# <label class="mp01500151" for="mp01500151">경남도민일보</label>
# </li>
# <li>
# <input class="local50" id="mp01500051" name="main_provider" type="checkbox" value="01500051"/>
# <label class="mp01500051" for="mp01500051">경남신문</label>
# </li>
# <li>
# <input class="local50" id="mp01500301" name="main_provider" type="checkbox" value="01500301"/>
# <label class="mp01500301" for="mp01500301">경상일보</label>
# </li>
# <li>
# <input class="local50" id="mp01500401" name="main_provider" type="checkbox" value="01500401"/>
# <label class="mp01500401" for="mp01500401">국제신문</label>
# </li>
# <li>
# <input class="local50" id="mp01500501" name="main_provider" type="checkbox" value="01500501"/>
# <label class="mp01500501" for="mp01500501">대구일보</label>
# </li>
# <li>
# <input class="local50" id="mp01500601" name="main_provider" type="checkbox" value="01500601"/>
# <label class="mp01500601" for="mp01500601">매일신문</label>
# </li>
# <li>
# <input class="local50" id="mp01500701" name="main_provider" type="checkbox" value="01500701"/>
# <label class="mp01500701" for="mp01500701">부산일보</label>
# </li>
# <li>
# <input class="local50" id="mp01500801" name="main_provider" type="checkbox" value="01500801"/>
# <label class="mp01500801" for="mp01500801">영남일보</label>
# </li>
# <li>
# <input class="local50" id="mp01500901" name="main_provider" type="checkbox" value="01500901"/>
# <label class="mp01500901" for="mp01500901">울산매일</label>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>
# <input id="localCheck60" name="localCheck" onclick="setLocalProvider(60, this);" type="checkbox"/>
# <label for="localCheck60"><b>전라</b></label>
# </th>
# <td colspan="3">
# <ul class="li_dan5">
# <li>
# <input class="local60" id="mp01600301" name="main_provider" type="checkbox" value="01600301"/>
# <label class="mp01600301" for="mp01600301">광주일보</label>
# </li>
# <li>
# <input class="local60" id="mp01600501" name="main_provider" type="checkbox" value="01600501"/>
# <label class="mp01600501" for="mp01600501">무등일보</label>
# </li>
# <li>
# <input class="local60" id="mp01600801" name="main_provider" type="checkbox" value="01600801"/>
# <label class="mp01600801" for="mp01600801">전남일보</label>
# </li>
# <li>
# <input class="local60" id="mp01601001" name="main_provider" type="checkbox" value="01601001"/>
# <label class="mp01601001" for="mp01601001">전북도민일보</label>
# </li>
# <li>
# <input class="local60" id="mp01601101" name="main_provider" type="checkbox" value="01601101"/>
# <label class="mp01601101" for="mp01601101">전북일보</label>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>
# <input id="localCheck70" name="localCheck" onclick="setLocalProvider(70, this);" type="checkbox"/>
# <label for="localCheck70"><b>제주</b></label>
# </th>
# <td colspan="3">
# <ul class="li_dan5">
# <li>
# <input class="local70" id="mp01700101" name="main_provider" type="checkbox" value="01700101"/>
# <label class="mp01700101" for="mp01700101">제민일보</label>
# </li>
# <li>
# <input class="local70" id="mp01700201" name="main_provider" type="checkbox" value="01700201"/>
# <label class="mp01700201" for="mp01700201">한라일보</label>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>
# <input id="localCheck70" name="localCheck" onclick="setLocalProvider(88, this);" type="checkbox"/>
# <label for="localCheck70"><b>방송사</b></label>
# </th>
# <td colspan="3">
# <ul class="li_dan5">
# <li>
# <input class="local88" id="mp08100201" name="main_provider" type="checkbox" value="08100201"/>
# <label class="mp08100201" for="mp08100201">MBC</label>
# </li>
# <li>
# <input class="local88" id="mp08200101" name="main_provider" type="checkbox" value="08200101"/>
# <label class="mp08200101" for="mp08200101">OBS</label>
# </li>
# <li>
# <input class="local88" id="mp08100301" name="main_provider" type="checkbox" value="08100301"/>
# <label class="mp08100301" for="mp08100301">SBS</label>
# </li>
# <li>
# <input class="local88" id="mp08100401" name="main_provider" type="checkbox" value="08100401"/>
# <label class="mp08100401" for="mp08100401">YTN</label>
# </li>
# </ul>
# </td>
# </tr>
# <tr>
# <tr class="none">
# <th>유형선택</th>
# <td colspan="3">
# <select class="w150" id="category1" onchange="changeCategory(1, this)">
# <option value="0">대분류를 선택하세요</option>
# </select>
# <label class="blind" for="category1">유형대분류</label>
# <select class="w150 ml5" id="category2" onchange="changeCategory(2, this)">
# <option value="0">중분류를 선택하세요</option>
# </select>
# <label class="blind" for="category2">유형중분류</label>
# <select class="w140 ml5" id="category3">
# <option value="0">소분류를 선택하세요</option>
# </select>
# <label class="blind" for="category3">유형소분류</label>
# <span class="buIcon btnTab mlr5">
# <input alt="분류추가" onclick="addCategory();" type="button" value="+ 추가"/>
# </span>
# <a href="javascript:fn_categoryInfo(2);">
# <img alt="기사 분류정보 보기(유형선택)" class="middle" src="/webcont/images/btn/bu_quest.png" title="유형 분류정보 보기 새창열림"/>
# </a>
# <input id="category_code" name="category_code" style="width:500px" type="hidden" value="">
# <input id="category_name" name="category_name" style="width:500px" type="hidden" value="">
# <ul class="listLidot mt10" id="categoryName">
# </ul>
# </input></input></td>
# </tr>
# <tr class="none">
# <th>사건사고선택</th>
# <td colspan="3">
# <select class="w150" id="incident1" onchange="changeIncident(0, this)">
# <option value="0">대분류를 선택하세요</option>
# <option value="|1|">범죄</option>
# <option value="|2|">사고</option>
# <option value="|3|">재해</option>
# <option value="|4|">사회</option>
# </select>
# <label class="blind" for="incident1">사건사고대분류</label>
# <select class="w150 ml5" id="incident2" onchange="changeIncident(1, this)">
# <option value="0">중분류를 선택하세요</option>
# </select>
# <label class="blind" for="incident2">사건사고중분류</label>
# <select class="w140 ml5" id="incident3">
# <option value="0">소분류를 선택하세요</option>
# </select>
# <label class="blind" for="incident3">사건사고소분류</label>
# <span class="buIcon btnTab mlr5">
# <input alt="분류추가" onclick="addIncident();" type="button" value="+ 추가"/>
# </span>
# <a href="javascript:fn_categoryInfo(3);">
# <img alt="기사 분류정보 보기(사건사고선택)" class="middle" src="/webcont/images/btn/bu_quest.png" title="사건사고 분류정보 보기 새창열림"/>
# </a>
# <input id="larm_incident_category_path" name="larm_incident_category_path" style="width:500px" type="hidden" value="">
# <input id="larm_incident_category_nm" name="larm_incident_category_nm" style="width:500px" type="hidden" value="">
# <ul class="listLidot mt10" id="incidentName">
# </ul>
# </input></input></td>
# </tr>
# <tr>
# <th>유형분류</th>
# <style>
# 								.jstree-themeicon { display:none !important; }
# 							</style>
# <td class="tree" colspan="2">
# <div class="treeBox" id="treeCMain">
# <ul class="treeCategoryMain">
# </ul>
# </div>
# </td>
# <th>사건/사고분류</th>
# <td class="tree">
# <div class="treeBox" id="treeIMain">
# <ul class="incidentCategoryMain">
# </ul>
# </div>
# </td>
# </tr>
# </tr>
#
#
# <div class="btnGroup_pop">
# <span class="button btnTypePopA"><input class="" onclick="clearSearch();" type="button" value="전체해제"/></span>
# <span class="button btnTypePopB"><input class="close1" onclick="fn_PreSearch();" type="button" value="검색"/></span>
# </div>
#
#
#
# <input id="btnValue" type="hidden">
# <script type="text/javascript">
# 	// 등록일 박스 선택 달력 보여주기
#  	$('#fromDate, #toDate').datepicker({
#  		showOn:"both",
#  		buttonImage:"/webcont/images/btn/bu_calender.gif",
# 		dateFormat:"yymmdd",
# 		showMonthAfterYear:true,
# 		changeMonth:true,
# 		changeYear:true,
# 		maxDate:0
# 	});
#
# 	function fn_PreSearch(){
# 		//유형
# 		var selectedElmsIdsC = $('#treeCMain').jstree("get_top_selected");
# 	    $("#category_code").val(selectedElmsIdsC.join(","));
# 	    var categoryNameTree = "";
# 	    for(var i = 0 ; i < selectedElmsIdsC.length ; i++){
# 	    	categoryNameTree += $("#"+selectedElmsIdsC[i].replace(/\|/gi, 'a')).html() + ",";
# 	    }
# 	    $("#category_name").val(categoryNameTree.substring(0, categoryNameTree.lastIndexOf(",")));
#
# 	    //사건사고
# 	    var selectedElmsIdsI = $('#treeIMain').jstree("get_top_selected");
# 	    $("#larm_incident_category_path").val(selectedElmsIdsI.join(","));
# 		var incidentNameTree = "";
# 	    for(var i = 0 ; i < selectedElmsIdsI.length ; i++){
# 	    	incidentNameTree += $("#"+selectedElmsIdsI[i].replace(/\|/gi, 'b')).html() + ",";
# 	    }
# 	    $("#larm_incident_category_nm").val(incidentNameTree.substring(0, incidentNameTree.lastIndexOf(",")));
#
# 	    //언론사
# 		var provider_selected = "";
# 		var provider_nm_selected = "";
# 		$("input[name=main_provider]:checkbox").each(function () {
# 		    if ($(this).is(":checked")) {
# 		    	provider_selected += $(this).val() + ",";
# 		    	provider_nm_selected += $("."+$(this).attr("id")).html() + ",";
# 		    }
# 		});
#
# 		provider_selected = provider_selected.substring(0, provider_selected.lastIndexOf(","));
# 		provider_nm_selected = provider_nm_selected.substring(0, provider_nm_selected.lastIndexOf(","));
#
# 		$("#providerCode").val(provider_selected);
# 	    $("#providerName").val(provider_nm_selected);
#
#
# 		fn_search('N');
# 	}
#
# 	function setLocalProvider(n, obj){
# 		//alert(obj.checked);
#
# 		$(".local"+n).prop("checked", obj.checked);
# 	}
#
#
# 	/* 상세검색 */
# 	function fn_detailSearch() {
# 		var f = document.topSearchForm;
#
# 		if( f.keyword.value != "" ) {
# 			$("#popKeyword").val($("#searchTotal").val());
# 		}
#
# 		//showPopup(1);
# 		showPopupDetailSearch(1);
# 	}
#
# 	function setDate(n){
#
# 		var dt = new Date();
# 		var today = dt.getFullYear().toString()  + (dt.getMonth() + 1).toString()  + dt.getDate().toString();
#
# 		var yyyyT = dt.getFullYear().toString();
# 	    var mmT = (dt.getMonth() + 1).toString();
# 	    var ddT = dt.getDate().toString();
#
#
#
#
# 		if(n == 0){
# 			$("#fromDate").val("");
# 			$("#toDate").val("");
# 		}
# 		else if(n == 1){
# 			$("#fromDate").val(yyyyT + (mmT[1] ? mmT : '0'+mmT[0]) + (ddT[1] ? ddT : '0'+ddT[0]));
# 			$("#toDate").val(yyyyT + (mmT[1] ? mmT : '0'+mmT[0]) + (ddT[1] ? ddT : '0'+ddT[0]));
# 		}
# 		else
# 		{
# 			dt.setDate(dt.getDate()-n);
#
# 			var yyyy = dt.getFullYear().toString();
# 		    var mm = (dt.getMonth() + 1).toString();
# 		    var dd = dt.getDate().toString();
#
# 		    $("#fromDate").val(yyyy + (mm[1] ? mm : '0'+mm[0]) + (dd[1] ? dd : '0'+dd[0]));
# 		    $("#toDate").val(yyyyT + (mmT[1] ? mmT : '0'+mmT[0]) + (ddT[1] ? ddT : '0'+ddT[0]));
# 		}
#
# 	}
#
# 	// selectbox
# 	function fn_add() {
#
# 		var _code = $("#providerCodeCombo").val();
#
# 		if($("#providerCode").val() != ""){
# 			var _codeList = $("#providerCode").val().split(",");
# 			for(var i = 0 ; i < _codeList.length ; i++){
# 				if(_codeList[i] == _code){
# 					alert("이미 추가된 언론사입니다.");
# 					return;
# 				}
# 			}
# 		}
#
# 		var str = "";
#
# 		if( _code != "0" ) {
# 			str += "<li class=\"iconT i_dotOran2 "+_code+"\">" + $("#providerCodeCombo option:selected").text();
# 			str += "	<span class=\"btn_del\" onclick=\"fn_remove('"+ _code +"');\">삭제</span>";
# 			str += "</li>";
#
# 			$("#proName").append(str);
#
# 			if($("#providerCode").val() == ""){
# 				$("#providerCode").val(_code);
# 				$("#providerName").val($("#providerCodeCombo option:selected").text());
# 			}
# 			else{
# 				$("#providerCode").val($("#providerCode").val() +','+ _code);
# 				$("#providerName").val($("#providerName").val() +','+ $("#providerCodeCombo option:selected").text());
# 			}
#
# 		}
#
# 	}
#
# 	// selectbox
# 	function fn_remove(_code) {
# 		var _codeList = $("#providerCode").val().split(",");
# 		var _nameList = $("#providerName").val().split(",");
#
#
# 		$("#providerCode").val("");
# 		$("#providerName").val("");
#
# 		for(var i = 0 ; i < _codeList.length ; i++){
#
# 			if(_codeList[i] != _code){
# 				if($("#providerCode").val() == ""){
# 					$("#providerCode").val(_codeList[i]);
# 					$("#providerName").val(_nameList[i]);
# 				}
# 				else{
# 					$("#providerCode").val($("#providerCode").val() +','+ _codeList[i]);
# 					$("#providerName").val($("#providerName").val() +','+ _nameList[i]);
# 				}
# 			}
#
# 		}
#
# 		$("."+_code).remove();
#
# 	}
#
# 	//fn_getCategory('000000270', '1');
#
# 	function fn_getCategory(_parent, _depth){
# 		$.ajax({
# 			type:"POST",
# 			url: "/search/getCategoryList.do",
# 			dataType:"json",
# 			data: {
# 				"parent_code" : _parent,
# 				"category_depth" : _depth
# 			},
# 			success:function( data ) {
# 				setCategory(data.categoryList, _depth);
# 			},
# 			error:function (xhr, ajaxOptions, thrownError) {
# 				alert("사용중 오류가 발생 하였습니다. \n관리자에게 문의 하시기 바랍니다.");
# 		    }
# 		});
# 	}
#
# 	function setCategory(data, _depth){
#
# 		var optionList = "";
#
# 		for(var i = 0 ; i < data.length ; i++){
# 			optionList += "<option value=\""+data[i].category_path+"\">"+data[i].category_name+"</option>";
# 		}
#
# 		if(_depth == 1){
# 			$("#category1").append(optionList);
# 		}
# 		else if(_depth == 2){
# 			$("#category2").append(optionList);
# 		}
# 		else if(_depth == 3){
# 			$("#category3").append(optionList);
# 		}
# 	}
#
# 	function changeCategory(_depth, obj){
#
# 		var _category_path = obj.value.split("|")[_depth];
#
# 		if(_depth == 1){
# 			$("#category2").html("");
# 			$("#category3").html("");
#
# 			$("#category2").append("<option value=\"0\">중분류를 선택하세요</option>");
# 			$("#category3").append("<option value=\"0\">소분류를 선택하세요</option>");
#
# 			fn_getCategory(_category_path, 2);
# 		}
# 		else if(_depth == 2){
#
# 			$("#category3").html("");
#
# 			$("#category3").append("<option value=\"0\">소분류를 선택하세요</option>");
#
# 			fn_getCategory(_category_path, 3);
# 		}
# 	}
#
# 	function addCategory(){
# 		var _name = "";
# 		var _code = "";
#
# 		if($("#category1").val() == 0){
# 			alert('추가할 유형을 선택해주세요.');
# 			return;
# 		}
#
# 		_code = $("#category1").val();
#
# 		_name = $("#category1 option:selected").text();
#
# 		if($("#category2").val() != 0){
# 			_name += " > " +$("#category2 option:selected").text();
# 			_code = $("#category2").val();
#
# 			if($("#category3").val() != 0){
# 				_name += " > " +$("#category3 option:selected").text();
# 				_code = $("#category3").val();
# 			}
# 		}
#
# 		_codeClass = _code.replace(/\|/g,"");
#
# 		var _li = "<li class=\"iconT i_dotOran2 "+_codeClass+"\">";
# 		_li += _name;
# 		_li += "<span class=\"btn_del\" onclick=\"fn_categoryRemove('"+ _code +"');\">삭제</span>";
# 		_li += "</li>"
#
# 		if($("#category_code").val() != ""){
# 			var _codeList = $("#category_code").val().split(",");
# 			for(var i = 0 ; i < _codeList.length ; i++){
# 				if(_codeList[i] == _code){
# 					alert("이미 추가된 유형입니다.");
# 					return;
# 				}
# 			}
# 		}
#
# 		if($("#category_name").val() == ""){
# 			$("#category_name").val(_name);
# 			$("#category_code").val(_code);
# 		}
# 		else{
# 			$("#category_name").val($("#category_name").val()+","+_name);
# 			$("#category_code").val($("#category_code").val()+","+_code);
# 		}
#
# 		$("#categoryName").append(_li);
# 	}
#
# 	function fn_categoryRemove(_code){
# 		var _codeList = $("#category_code").val().split(",");
# 		var _nameList = $("#category_name").val().split(",");
#
#
# 		$("#category_code").val("");
# 		$("#category_name").val("");
#
# 		for(var i = 0 ; i < _codeList.length ; i++){
#
# 			if(_codeList[i] != _code){
# 				if($("#category_code").val() == ""){
# 					$("#category_code").val(_codeList[i]);
# 					$("#category_name").val(_nameList[i]);
# 				}
# 				else{
# 					$("#category_code").val($("#category_code").val() +','+ _codeList[i]);
# 					$("#category_name").val($("#category_name").val() +','+ _nameList[i]);
# 				}
# 			}
#
# 		}
#
# 		$("."+_code.replace(/\|/g,"")).remove();
#
# 	}
#
# 	//fn_getIncident('', '0');
#
# 	function fn_getIncident(_parent, _depth){
#
# 		$.ajax({
# 			type:"POST",
# 			url: "/search/getIncidentList.do",
# 			dataType:"json",
# 			data: {
# 				"larm_incident_category_level" : _depth,
# 				"larm_incident_category_upper_path" : _parent
# 			},
# 			success:function( data ) {
# 				setIncident(data.incidentList, _depth);
# 			},
# 			error:function (xhr, ajaxOptions, thrownError) {
# 				alert("사용중 오류가 발생 하였습니다. \n관리자에게 문의 하시기 바랍니다.");
# 		    }
# 		});
# 	}
#
#
# 	function setIncident(data, _depth){
# 		var optionList = "";
#
# 		for(var i = 0 ; i < data.length ; i++){
# 			optionList += "<option value=\""+data[i].larm_incident_category_path+"\">"+data[i].larm_incident_category_nm+"</option>";
# 		}
#
# 		if(_depth == 0){
# 			$("#incident1").append(optionList);
# 		}
# 		else if(_depth == 1){
# 			$("#incident2").append(optionList);
# 		}
# 		else if(_depth == 2){
# 			$("#incident3").append(optionList);
# 		}
# 	}
#
# 	function changeIncident(_depth, obj){
# 		var _category_path = obj.value;
#
# 		if(_depth == 0){
# 			$("#incident2").html("");
# 			$("#incident3").html("");
#
# 			$("#incident2").append("<option value=\"0\">중분류를 선택하세요</option>");
# 			$("#incident3").append("<option value=\"0\">소분류를 선택하세요</option>");
#
# 			fn_getIncident(_category_path, 1);
# 		}
# 		else if(_depth == 1){
#
# 			$("#incident3").html("");
#
# 			$("#incident3").append("<option value=\"0\">소분류를 선택하세요</option>");
#
# 			fn_getIncident(_category_path, 2);
# 		}
# 	}
#
# 	function addIncident(){
# 		var _name = "";
# 		var _code = "";
#
# 		if($("#incident1").val() == 0){
# 			alert('추가할 사건사고를 선택해주세요.');
# 			return;
# 		}
#
# 		_code = $("#incident1").val();
#
# 		_name = $("#incident1 option:selected").text();
#
# 		if($("#incident2").val() != 0){
# 			_name += " > " +$("#incident2 option:selected").text();
# 			_code = $("#incident2").val();
#
# 			if($("#incident3").val() != 0){
# 				_name += " > " +$("#incident3 option:selected").text();
# 				_code = $("#incident3").val();
# 			}
# 		}
#
# 		_codeClass = _code.replace(/\|/g,"");
#
# 		var _li = "<li class=\"iconT i_dotOran2 "+_codeClass+"\">";
# 		_li += _name;
# 		_li += "<span class=\"btn_del\" onclick=\"fn_incidentRemove('"+ _code +"');\">삭제</span>";
# 		_li += "</li>"
#
# 		if($("#larm_incident_category_path").val() != ""){
# 			var _codeList = $("#larm_incident_category_path").val().split(",");
# 			for(var i = 0 ; i < _codeList.length ; i++){
# 				if(_codeList[i] == _code){
# 					alert("이미 추가된 사건사고입니다.");
# 					return;
# 				}
# 			}
# 		}
#
# 		if($("#larm_incident_category_nm").val() == ""){
# 			$("#larm_incident_category_nm").val(_name);
# 			$("#larm_incident_category_path").val(_code);
# 		}
# 		else{
# 			$("#larm_incident_category_nm").val($("#larm_incident_category_nm").val()+","+_name);
# 			$("#larm_incident_category_path").val($("#larm_incident_category_path").val()+","+_code);
# 		}
#
# 		$("#incidentName").append(_li);
# 	}
#
# 	function fn_incidentRemove(_code) {
# 		var _codeList = $("#larm_incident_category_path").val().split(",");
# 		var _nameList = $("#larm_incident_category_nm").val().split(",");
#
#
# 		$("#larm_incident_category_path").val("");
# 		$("#larm_incident_category_nm").val("");
#
# 		for(var i = 0 ; i < _codeList.length ; i++){
#
# 			if(_codeList[i] != _code){
# 				if($("#larm_incident_category_path").val() == ""){
# 					$("#larm_incident_category_path").val(_codeList[i]);
# 					$("#larm_incident_category_nm").val(_nameList[i]);
# 				}
# 				else{
# 					$("#larm_incident_category_path").val($("#larm_incident_category_path").val() +','+ _codeList[i]);
# 					$("#larm_incident_category_nm").val($("#larm_incident_category_nm").val() +','+ _nameList[i]);
# 				}
# 			}
#
# 		}
#
# 		$("."+_code.replace(/\|/g,"")).remove();
#
# 	}
#
# 	function clickField() {
# 		$("#search_field").val($('input:radio[name="fieldRadio"]:checked').val());
# 	}
#
# 	function clickMethod() {
# 		$("#search_method").val($('input:radio[name="methodRadio"]:checked').val());
# 		//alert($("#search_method").val());
# 	}
#
#
#
#
# 	function changeProvider() {
# 		var _m = $("#mediaCodeCombo").val();
# 		var _a = $("#areaCodeCombo").val();
#
#
# 		$.ajax({
# 			type:"POST",
# 			url: "/search/getProviderList.do",
# 			dataType:"json",
# 			data: {
# 				"area_code" : _a,
# 				"media_code" : _m
# 			},
# 			success:function( data ) {
# 				setProviderList(data.providerList);
# 			},
# 			error:function (xhr, ajaxOptions, thrownError) {
# 				alert("사용중 오류가 발생 하였습니다. \n관리자에게 문의 하시기 바랍니다.");
# 		    }
# 		});
# 	}
#
# 	function setProviderList(data){
# 		$("#providerCodeCombo").html("");
#
# 		var optionList = '<option value="0">언론사를 선택하세요</option>';
#
# 		for(var i = 0 ; i < data.length ; i++){
# 			optionList += "<option value=\""+data[i].provider_code+"\">"+data[i].provider_name+"</option>";
# 		}
#
#
#
# 		$("#providerCodeCombo").append(optionList);
# 	}
#
# 	function fn_categoryInfo( str ) {
# 		var f = document.categoryInfoForm;
#
# 		f.cateFlag.value = str;
#
#
# 		f.action = "/help/helpCategoryInfo.do";
# 		f.submit();
# 	}
#
# 	//검색조건 트리
# 	getMainTreeData();
#
# 	function getMainTreeData(){
#
# 		var defaultCategory = '';
# 		var defaultIncident = '';
#
#
# 		$.ajax({
# 			type:"POST",
# 			url:"/search/treeTest.do",
# 			dataType:"json",
# 			data:{
# 				"date" : ""
# 			},
# 			success:function( data ) {
# 				setCategoryTreeMain(data, defaultCategory, defaultIncident);
# 			},
# 			error:function (xhr, ajaxOptions, thrownError) {
# 				//alert("사용중 오류가 발생 하였습니다. \n관리자에게 문의 하시기 바랍니다.");
# 		    }
# 		});
# 	}
#
# 	function checkTree(obj, value){
# 		for(var i = 0 ; i < obj.length ; i++){
# 			if(obj[i] == value){
# 				return true;
# 			}
# 		}
#
# 		return false;
# 	}
#
#
# 	function setCategoryTreeMain(data, defaultCategory, defaultIncident){
# 		setIncidentTreeMain(data, defaultIncident);
#
# 		var treeData = data.categoryTreeList;
# 		var parentCode = "";
#
# 		var treeText = "";
# 		var treeText0 = "";
#
# 		var currentDepth = 1;
#
# 		var dcTree = defaultCategory.split(",");
#
# 		for(var i = 0 ; i < treeData.length ; i++){
# 			var treeItem = treeData[i];
# 			var treeCode = treeItem.category_code;
# 			var treeDepth = treeItem.category_depth;
# 			var treeName = treeItem.category_name;
# 			var treePath = treeItem.category_path;
# 			var subCnt = treeItem.listCount;
#
# 			if(treePath.match('000000277') || treePath.match('000000334')){
# 				if((parentCode != treeItem.parent_code && parentCode != "" || treeDepth == 1) && i != 0){
# 					treeText0 += '</ul>';
# 					parentCode = "";
# 				}
#
# 				if(defaultCategory == ""){
# 					treeText0 += '<li id="'+treePath+'" data-jstree=\'{\"opened\":true}\' >';
# 				}
# 				else{
# 					if(checkTree(dcTree, treePath)){
# 						treeText0 += '<li id="'+treePath+'" data-jstree=\'{\"opened\":true,\"selected\":true}\' >';
# 					}
# 					else{
# 						treeText0 += '<li id="'+treePath+'" data-jstree=\'{\"opened\":true}\' >';
# 					}
# 				}
#
#
# 				//treeText0 += '<label for="'+treePath+'" >'+treeName+'</label>';
# 				treeText0 += '<label for="'+treePath+'" id="'+treePath.replace(/\|/gi, 'a') +'">'+treeName+'</label>';
#
# 				if(subCnt > 0){
# 					parentCode = treeCode;
# 					treeText0 += '<ul>';
# 				}
#
# 			}
# 			else{
# 				if((parentCode != treeItem.parent_code && parentCode != "" || treeDepth == 1) && i != 0){
# 					treeText += '</ul>';
# 					parentCode = "";
# 				}
#
# 				if(defaultCategory == ""){
# 					treeText += '<li id="'+treePath+'" data-jstree=\'{\"opened\":true}\' >';
# 				}
# 				else{
# 					if(checkTree(dcTree, treePath)){
# 						treeText += '<li id="'+treePath+'" data-jstree=\'{\"opened\":true,\"selected\":true}\' >';
# 					}
# 					else{
# 						treeText += '<li id="'+treePath+'" data-jstree=\'{\"opened\":true}\' >';
# 					}
# 				}
#
# 				//treeText += '<label for="'+treePath+'" >'+treeName+'</label>';
# 				treeText += '<label for="'+treePath+'" id="'+treePath.replace(/\|/gi, 'a') +'">'+treeName+'</label>';
#
# 				if(subCnt > 0){
# 					parentCode = treeCode;
# 					treeText += '<ul>';
# 				}
# 			}
#
# 		}
#
# 		treeText = treeText0 + treeText;
#
# 		if(treeText.split('<ul>').length != treeText.split('</ul>').length){
# 			treeText += "</ul>";
# 		}
#
# 		$(".treeCategoryMain").html(treeText);
#
# 		$('#treeCMain').jstree({
# 	           "checkbox": {
# 	               real_checkboxes: true
# 	            },
# 	            "plugins": ["themes", "json_data", "ui", "checkbox"]
# 	         });
#
# 	}
#
# 	function setIncidentTreeMain(data, defaultIncident){
#
# 		var treeData = data.incidentTreeList;
# 		var parentCode = "";
#
# 		var treeText = "";
#
# 		var currentDepth = 1;
#
# 		var diTree = defaultIncident.split(",");
#
# 		for(var i = 0 ; i < treeData.length ; i++){
# 			var treeItem = treeData[i];
# 			var treeCode = treeItem.category_code;
# 			var treeDepth = treeItem.category_depth;
# 			var treeName = treeItem.category_name;
# 			var treePath = treeItem.category_path;
# 			var subCnt = treeItem.listCount;
#
# 			if((parentCode != treeItem.parent_code && parentCode != "" || treeDepth == 1) && i != 0){
# 				treeText += '</ul>'		+ "\n";
# 				parentCode = "";
# 				if( treeDepth == 1 && i != 0){
# 					treeText += '</ul>'		+ "\n";
# 				}
# 			}
#
# 			if(defaultIncident == ""){
# 				treeText += '<li id="'+treePath+'" data-jstree=\'{\"opened\":true}\' >';
# 			}
# 			else{
# 				if(checkTree(diTree, treePath)){
# 					treeText += '<li id="'+treePath+'" data-jstree=\'{\"opened\":true,\"selected\":true}\' >';
# 				}
# 				else{
# 					treeText += '<li id="'+treePath+'" data-jstree=\'{\"opened\":true}\' >';
# 				}
# 			}
#
# 			treeText += '<label for="'+treePath+'"  id="'+treePath.replace(/\|/gi, 'b') +'">'+treeName+'</label>';
#
#
# 			if(subCnt > 0){
# 				parentCode = treeCode;
# 				treeText += '<ul>';
# 			}
#
# 		}
#
# 		if(treeText.split('<ul>').length != treeText.split('</ul>').length){
# 			treeText += "</ul>";
# 		}
#
# 		$(".incidentCategoryMain").html(treeText);
#
# 		$('#treeIMain').jstree({
# 	           "checkbox": {
# 	               real_checkboxes: true
# 	            },
# 	            "plugins": ["themes", "json_data", "ui", "checkbox"]
# 	         });
#
# 	}
#
# </script>
# </input>
#
# <div class="bu_searchDetail">
# <span class="button btnTypeA">
# <input id="" onclick="fn_detailSearch();" type="button" value="상세검색">
# </input></span>
# </div>
#
#
# <!--E: header -->
# <form action="/search/totalSearchNewsView.do" mehod="post" name="articleViewForm">
# <input id="view_news_id" name="news_id" type="hidden">
# </input></form>
# <form action="/help/helpCategoryInfo.do" method="post" name="categoryInfoForm" target="_blank">
# <input id="cateFlag" name="cateFlag" type="hidden" value="">
# </input></form>
# <script type="text/javascript">
# 	$.ajax({
# 		type:"POST",
# 		url:"/popularSearchWordList.do",
# 		dataType:"json",
# 		data:{
# 			"date" : ""
# 		},
# 		success:function( data ) {
# 			$(".popularSearchWord").html();
# 			$.each( data.searchWordList, function(i) {
# 				var htmlStr = "";
#
# 				htmlStr += "<li><a href=\"javascript:setPopKeyword('"+data.searchWordList[i].query+"');\">" + data.searchWordList[i].query + "</a></li>";
#
#
# 				$(".popularSearchWord").append(htmlStr);
# 			});
# 		},
# 		error:function (xhr, ajaxOptions, thrownError) {
# 			//alert("사용중 오류가 발생 하였습니다. \n관리자에게 문의 하시기 바랍니다.");
# 	    }
# 	});
#
# 	/* 페이지 이동 - 아이콘 */
# 	function fn_movePage( str ) {
# 		var f = document.topSearchForm;
#
# 		f.keyword.value = "";
#
# 		if( str == "M" ) {							// 메인화면
# 			f.action = "/search/totalSearchMain.do";
# 		} else if( str == "L" ) {					// 로그인화면
# 			f.action = "/member/loginPage.do";
# 		} else if( str == "" ) {					// 회원가입화면
# 			f.action = "";
# 		} else if( str == "" ) {					// 로그아웃화면
# 			f.action = "";
# 		} else if( str == "H" ) {					// 고객센터화면
# 			f.action = "/help/helpFaqList.do";
# 		} else if( str == "S" ) {					// 사이트맵
# 			f.action = "/help/helpSiteMap.do";
# 		}
#
# 		f.submit();
# 	}
#
# 	/* 검색 */
# 	function fn_searchO() {
# 		var f = document.topSearchForm;
#
# 		f.action = "/search/totalSearchList.do";
# 		f.submit();
# 	}
#
# 	/* 엔터키 체크 */
# 	function keyCheck( e ) {
# 		if( e.keyCode == 13 ) {
# 			fn_search();
# 			return;
# 		}
# 	}
#
#
# </script>
# ...
#
# 									YTN I
#
# 									2017.10.07
# 									 I
# 								</span>
# </dt>
# <dd>
# <a href="/search/totalSearchView.do?news_id=08100401.20171007102802001"><font color="1171CA"><b>문재인</b></font> 정부 출범 후 시민들의 청와대 관람 신청이 크게 늘어 지금 신청해도 내년 2월에야 볼 수 있는 것으로 나타났습니다.  청와대 경내는 매주 화요일부터 금요일, 둘째·넷째 주 토요일에 관람할 수 있는..<font color="1171CA"><b>문재인</b></font> 정부가 출범한 5월부터 9월까지는 월평균 2만2천백여 명으로 관람객 수가 3.35배 늘었습니다.</a>
# </dd>
# </dl>
# </div>
# </div>
# <!--E: .list -->
# <!--S: .paging -->
# <script type="text/javascript">
# 		function fn_pageNavi( param ) {
# 			document.frmPageNavigator.listPage.value=param;
# 			document.frmPageNavigator.submit();
# 		}
# </script>
#  <div class="paging">
# <legend>페이징</legend>
# <a alt="처음페이지" class="bu ppre" href="javascript:fn_pageNavi(1);"></a>
# <a alt="이전페이지" class="bu pre" href="#"></a>
# <strong>1</strong>
# <a href="javascript:fn_pageNavi(2);">2</a>
# <a href="javascript:fn_pageNavi(3);">3</a>
# <a href="javascript:fn_pageNavi(4);">4</a>
# <a href="javascript:fn_pageNavi(5);">5</a>
# <a href="javascript:fn_pageNavi(6);">6</a>
# <a href="javascript:fn_pageNavi(7);">7</a>
# <a href="javascript:fn_pageNavi(8);">8</a>
# <a href="javascript:fn_pageNavi(9);">9</a>
# <a href="javascript:fn_pageNavi(10);">10</a>
# <a alt="다음페이지" class="bu next" href="javascript:fn_pageNavi(11);"></a>
# <a alt="마지막페이지" class="bu nnext" href="javascript:fn_pageNavi(43239);"></a>
# </div>
# <!--E: .paging -->
# </div>
# </div>
# <!--E: sectionA -->
# <!--S: sectionB -->
# <div id="sectionB">
# <!--S: R_box#1 -->
# <div class="R_box">
# <div class="sectionTitle">
# <h2 class="label t02"><span class="text">연관이슈</span></h2>
# </div>
# <ul>
# <li><p class="center" id="wcp"><svg id="wc"></svg></p></li>
# </ul>
# </div>
# <!--E: R_box#1 -->
# <!--S: R_box#2 -->
# <div class="R_box">
# <div class="sectionTitle">
# <h2 class="label t03"><span class="text">오늘의 이슈</span></h2>
# </div>
# <ol class="number">
# <li>
# <a href="javascript:fn_selectIssue('todayIssue0')" id="todayIssue0" value="세탁기 미국 삼성 산업 피해 판정 ">
# 							세탁기 미국 삼성 산업 피해 판정
# 						</a>
# </li>
# <li>
# <a href="javascript:fn_selectIssue('todayIssue1')" id="todayIssue1" value="안동 취임 하회마을 대통령 방문 ">
# 							안동 취임 하회마을 대통령 방문
# 						</a>
# </li>
# <li>
# <a href="javascript:fn_selectIssue('todayIssue2')" id="todayIssue2" value="트럼프 용납 이란 위협 협상 예방 ">
# 							트럼프 용납 이란 위협 협상 예방
# 						</a>
# </li>
# <li>
# <a href="javascript:fn_selectIssue('todayIssue3')" id="todayIssue3" value="여중생 30대 살해 시신 용의자 유기 검거 ">
# 							여중생 30대 살해 시신 용의자 유기 검거
# 						</a>
# </li>
# <li>
# <a href="javascript:fn_selectIssue('todayIssue4')" id="todayIssue4" value="노벨평화상 핵무기 국제운동 수상 ">
# 							노벨평화상 핵무기 국제운동 수상
# 						</a>
# </li>
# <li>
# <a href="javascript:fn_selectIssue('todayIssue5')" id="todayIssue5" value="날씨 전국 안개 일교차 귀경 조심 주의 ">
# 							날씨 전국 안개 일교차 귀경 조심 주의
# 						</a>
# </li>
# <li>
# <a href="javascript:fn_selectIssue('todayIssue6')" id="todayIssue6" value="노벨문학상 가즈오 이시구로 평화상 ">
# 							노벨문학상 가즈오 이시구로 평화상
# 						</a>
# </li>
# <li>
# <a href="javascript:fn_selectIssue('todayIssue7')" id="todayIssue7" value="개성공단 공장 가동설 상관 시인 ">
# 							개성공단 공장 가동설 상관 시인
# 						</a>
# </li>
# <li>
# <a href="javascript:fn_selectIssue('todayIssue8')" id="todayIssue8" value="중국 유조선 어선 충돌 사망 실종 ">
# 							중국 유조선 어선 충돌 사망 실종
# 						</a>
# </li>
# <li>
# <a href="javascript:fn_selectIssue('todayIssue9')" id="todayIssue9" value="한미 안철수 재협상 정부 대통령 사과 ">
# 							한미 안철수 재협상 정부 대통령 사과
# 						</a>
# </li>
# </ol>
# </div>
# <!--E: R_box#2 -->
# </div>
# <!--E: sectionB -->
# </div>
# </div>
# <!--E: document -->
# <div class="modal w800" id="popupLayer2" style="display:none">
# <div class="popLayerWrap">
# <header class="popLayerHeader">
# <h1 class="popLayerTitle">메타데이터 보기</h1>
# <input alt="팝업닫기" class="btnLayerClose close2" src="/webcont/images/btn/btn_close.gif" type="image">
# </input></header>
# <div class="popLayerContent">
# <!-- 조건 -->
# <div class="board pop">
# <!-- 버튼영역 -->
# <div class="btnR ptb10">
# <span class="buIcon btnTypeAicon">
# <a href="javascript:fn_metaDown();"><img alt="버튼 이미지" src="/webcont/images/ico/bu_icon04.png"/> 다운로드</a>
# </span>
# </div>
# <!-- 게시판 -->
# <div class="boardItem">
# <table>
# <caption>게시판 항목</caption>
# <colgroup>
# <col style="width:12%">
# <col style="width:*"/>
# <col style="width:11%"/>
# <col style="width:14%"/>
# <col style="width:14%"/>
# <col style="width:14%"/>
# </col></colgroup>
# <thead>
# <tr>
# <td>날짜</td>
# <td>제목</td>
# <td>매체</td>
# <td>P</td>
# <td>L</td>
# <td>O</td>
# </tr>
# </thead>
# </table>
# </div>
# <!-- 내용리스트 -->
# <table class="boardList">
# <caption>게시판 리스트</caption>
# <colgroup>
# <col style="width:12%"/>
# <col style="width:*"/>
# <col style="width:11%"/>
# <col style="width:14%"/>
# <col style="width:14%"/>
# <col style="width:14%"/>
# </colgroup>
# <!-- 검색결과 없을 경우
# 					<tbody>
# 						<tr>
# 							<td colspan="8">문의하신 내역이 없습니다.</td>
# 						</tr>
# 					</tbody> -->
# <!-- 검색리스트 -->
# <tbody>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">[연휴에 다시 볼만한 영화 ‘노무현입니다’]우리가 사랑했던 노무현에 ..</a></td>
# <td>서울경제</td>
# <td>유시민(0)</td>
# <td>종로구</td>
# <td>사람들의 모임</td>
# </tr>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">정미홍, 김빈 ‘관종’ 발언에 분노…“가만히 있는 사람 자꾸 건드려”</a></td>
# <td>서울경제</td>
# <td>문재인(0)</td>
# <td></td>
# <td>더불어민주당</td>
# </tr>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">내달부터 65세 이상 틀니 본인부담률 50%→30% 대폭 인하</a></td>
# <td>서울경제</td>
# <td>문재인(0)</td>
# <td>서울</td>
# <td>치과보철학회</td>
# </tr>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">[미리보는 국감] 기재위, 소득주도성장면세점담뱃세 논란에 '후끈'</a></td>
# <td>뉴스핌</td>
# <td>박근혜(0)</td>
# <td>종로구</td>
# <td>국민의당</td>
# </tr>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">되살아나는 부동산 시장… ‘주머니 속 카드’ 또 꺼내나</a></td>
# <td>헤럴드경제</td>
# <td>문재인(0)</td>
# <td>서울</td>
# <td>송파구</td>
# </tr>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">초과이익환수제 부활까지 석달… 논란은 계속 중</a></td>
# <td>헤럴드경제</td>
# <td>최현일(0)</td>
# <td>서울</td>
# <td>강남</td>
# </tr>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">靑, 추석 막바지 北도발 가능성 예의주시… NSC 비상가동</a></td>
# <td>서울신문</td>
# <td>문재인(0)</td>
# <td>미국</td>
# <td>청와대</td>
# </tr>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">靑, 北 추가 도발 예의주시..."도발 징후는 아직"</a></td>
# <td>YTN</td>
# <td>문재인(0)</td>
# <td></td>
# <td>청와대</td>
# </tr>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">치매, 알면 이긴다…치매국가책임제 활용법</a></td>
# <td>한겨레</td>
# <td>문재인(0)</td>
# <td></td>
# <td>보건복지부</td>
# </tr>
# <tr>
# <td>2017.10.07</td>
# <td class="title"><a href="#">靑 관람객 증가...지금 신청해도 내년 2월 가능</a></td>
# <td>YTN</td>
# <td>박근혜(0)</td>
# <td></td>
# <td>청와대</td>
# </tr>
# </tbody>
# </table>
# <!-- 페이징 -->
# <!-- <div class="paging pop">
# 					<legend>페이징</legend>
# 					<a alt="처음페이지" class="bu ppre" href=""></a>
# 					<a alt="이전페이지" class="bu pre" href=""></a>
# 					<strong>1</strong>
# 					<a href="">2</a>
# 					<a href="">3</a>
# 					<a href="">4</a>
# 					<a href="">5</a>
# 					<a href="">6</a>
# 					<a href="">7</a>
# 					<a href="">8</a>
# 					<a href="">9</a>
# 					<a href="">10</a>
# 					<a alt="다음페이지" class="bu next" href=""></a>
# 					<a alt="마지막페이지" class="bu nnext" href=""></a>
# 				</div> -->
# </div>
# </div>
# </div>
# </div>
# <div class="modal w450" id="popupLayer21" style="display:none">
# <form id="folder_form">
# <div class="popLayerWrap">
# <header class="popLayerHeader">
# <h1 class="popLayerTitle">뉴스 스크랩</h1>
# <input alt="팝업닫기" class="btnLayerClose close21" src="/webcont/images/btn/btn_close.gif" type="image">
# </input></header>
# <div class="popLayerContent">
# <ul class="listLidot">
# <li class="iconT i_dotOran2">선택하신 폴더에 검색결과를 스크랩 합니다</li>
# </ul>
# <!-- 폴더리스트 -->
# <div class="boardWrite folderListbox">
# <table class="listC">
# <caption>폴더리스트</caption>
# <colgroup>
# <col style="width:*"/>
# <col style="width:20%"/>
# </colgroup>
# <tbody>
# <tr>
# <th>폴더제목(스크랩수)</th>
# <th>생성일</th>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="btnGroup_pop">
# <span class="button btnTypeC"><input class="close21" onclick="scrapAnalResult();" type="button" value="확인"/></span>
# <span class="button btnTypeC"><input class="close21" type="button" value="취소"/></span>
# </div>
# </div>
# </div>
# </form>
# </div>
# <form id="listForm" method="post" name="listForm">
# <input id="keyword" name="keyword" type="hidden" value="문재인">
# <input name="news_id" type="hidden" value="">
# <input name="listPage" type="hidden" value="1">
# <input name="listCount" type="hidden" value="10">
# <input name="fromDate" type="hidden" value="">
# <input name="toDate" type="hidden" value="">
# <input name="orderByOption" type="hidden" value="desc">
# <input name="provider_code" type="hidden" value="">
# <input name="provider_name" type="hidden" value="">
# <input name="category_code" type="hidden" value="">
# <input name="category_name" type="hidden" value="">
# <input name="larm_incident_category_path" type="hidden" value="">
# <input name="larm_incident_category_nm" type="hidden" value="">
# <input name="search_field" type="hidden" value="_search">
# <input name="search_method" type="hidden" value="0">
# <input name="realKeyword" type="hidden" value="">
# <input name="keywordType" type="hidden" value="N">
# <input name="byline" type="hidden" value="">
# </input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></form>
# <form id="trendForm" method="post" name="trendForm">
# <input id="mediaQuery" name="mediaQuery" type="hidden" value=""/>
# <input id="startDate" name="startDate" type="hidden" value=""/>
# <input id="endDate" name="endDate" type="hidden" value=""/>
# <input id="lastQuery" name="lastQuery" type="hidden" value=""/>
# <input id="startPage" name="startPage" type="hidden" value="1"/>
# <input id="sort" name="sort" type="hidden" value="score"/>
# <input id="searchField" name="searchField" type="hidden" value="IN2_INTEGRATION"/>
# </form>
# <form action="/search/totalSearchList.do" id="frmPageNavigator" method="post" name="frmPageNavigator">
# <input name="listPage" type="hidden" value="1">
# <input name="listCount" type="hidden" value="10">
# <input id="cloudKeyword" name="keyword" type="hidden" value="문재인">
# <input name="orderByOption" type="hidden" value="desc">
# <input name="fromDate" type="hidden" value="">
# <input name="toDate" type="hidden" value="">
# <input id="defaultPC" name="provider_code" type="hidden" value="">
# <input id="defaultPN" name="provider_name" type="hidden" value="">
# <input id="defaultCC" name="category_code" type="hidden" value="">
# <input id="defaultCN" name="category_name" type="hidden" value="">
# <input id="defaultIC" name="larm_incident_category_path" type="hidden" value="">
# <input id="defaultIN" name="larm_incident_category_nm" type="hidden" value="">
# <input id="defaultField" name="search_field" type="hidden" value="_search">
# <input id="defaultMethod" name="search_method" type="hidden" value="0">
# <input id="defaultRK" name="realKeyword" type="hidden" value="">
# <input id="defaultKT" name="keywordType" type="hidden" value="N">
# <input id="defaultbyline" name="byline" type="hidden" value="">
# </input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></input></form>
# <script type="text/javascript">
# <!--
# 	/* 기사정렬 */
# 	function fn_orderBySearch( str ) {
# 		var f = document.listForm;
#
# 		f.listPage.value = "1";
# 		f.orderByOption.value = str;
# 		f.action = "/search/totalSearchList.do";
# 		f.submit();
# 	}
#
#
# 	/* 세부tab 이동 */
# 	function fn_moveTab( str ) {
# 		var f = document.listForm;
#
# 		if( str == "L") {
# 			f.action = "/search/totalSearchList.do";
# 		} else if( str == "H" ) {
# 			f.action = "/search/totalSearchHistory.do";
# 		} else if( str == "C" ) {
# 			f.action = "/search/totalSearchChart.do";
# 		} else if( str == "D" ) {
# 			f.action = "/search/totalSearchIndepthSub.do";
# 		}
#
# 		f.submit();
# 	}
#
# 	/* 메타데이터 다운 */
# 	function fn_metaDown(){
#
#
# 		var f = document.topSearchForm;
# 		f.action = "/excelMetaDownLoad.do";
# 		f.submit();
# 		return false;
# 	}
#
# 	/* 상세화면보기 */
# 	function fn_view( str ) {
# 		var f = document.listForm;
#
# 		f.news_id.value = str;
# 		f.action = "/search/totalSearchView.do";
# 		f.submit();
# 	}
#
# 	/* 메타데이터 팝업 */
# 	function fn_metaDataPop() {
# 		showPopup(2);
# 	}
#
#
# 	callWordCloud(0);
#
# 	function callWordCloud(n){
#
# 		if($("#defaultKT").val() == "N" || $("#defaultKT").val() == ""){
# 			$.ajax({
# 				type:"POST",
# 				url: "/topickData.do",
# 				dataType:"json",
# 				data: {
# 					//"keyword" : $("#a"+n).html()
# 					//"keyword" : '문재인',
# 					"keyword" : $("#cloudKeyword").val(),
# 					"fromDate" : '',
# 					"toDate" : '',
# 					"provider_code" : '',
# 					"category_code" : '',
# 					"larm_incident_category_path" : ''
# 				},
# 				success:function( data ) {
# 					setWordCloud(data);
# 				},
# 				error:function (xhr, ajaxOptions, thrownError) {
# 					//alert("사용중 오류가 발생 하였습니다. \n관리자에게 문의 하시기 바랍니다.");
# 			    }
# 			});
# 		}
# 		else{
# 			$.ajax({
# 				type:"POST",
# 				url: "/topickData.do",
# 				dataType:"json",
# 				data: {
# 					//"keyword" : $("#a"+n).html()
# 					"keyword" : '',
# 					"fromDate" : '',
# 					"toDate" : '',
# 					"provider_code" : '',
# 					"category_code" : '',
# 					"larm_incident_category_path" : ''
# 				},
# 				success:function( data ) {
# 					setWordCloud(data);
# 				},
# 				error:function (xhr, ajaxOptions, thrownError) {
# 					//alert("사용중 오류가 발생 하였습니다. \n관리자에게 문의 하시기 바랍니다.");
# 			    }
# 			});
# 		}
#
#
#
# 	}
#
# 	setSearchOption();
#
#
#
# 	function showScrapPop(){
# 		showPopup(21);
# 	}
#
# 	function showScrapPopLogout(){
# 		alert('로그인 후 이용하실 수 있습니다.');
# 		location.href = "/member/loginPage.do";
# 	}
#
# 	function scrapAnalResult(){
# 		var targetFolder = $("input[name='folder_radio']:checked").val();
#
# 		var _type = "";
#
# 		if($("#defaultField").val() == "_search"){
# 			_type = "A";
# 		}
# 		else if($("#defaultField").val() == "title"){
# 			_type = "T";
# 		}
# 		else{
# 			_type = "C";
# 		}
#
# 		var scrapKeyword = "";
#
# 		if($("#defaultKT").val() == "A"){
# 			scrapKeyword = $("#defaultRK").val();
# 		}
# 		else{
# 			scrapKeyword = $("#keyword").val();
# 		}
#
# 		$.ajax({
# 			type:"POST",
# 			url: "/personal/scrapAnalResult.do",
# 			dataType:"json",
# 			data: {
# 				"folder_id" : targetFolder,
# 				"serach_type" : _type,
# 				"srchwrd" : scrapKeyword,
# 				"search_start_date" : setDateFormat2($("#fromDate").val()),
# 				"search_end_date" : setDateFormat2($("#toDate").val()),
# 				"search_provider_code" : $("#defaultPC").val(),
# 				"search_provider_nm" : $("#defaultPN").val(),
# 				"search_incident_category_path" : $("#defaultIC").val(),
# 				"search_incident_category_nm" : $("#defaultIN").val(),
# 				"search_category_path" : $("#defaultCC").val(),
# 				"search_category_nm" : $("#defaultCN").val()
#
# 			},
# 			success:function( data ) {
# 				if(data.result == "Y"){
# 					alert('검색결과가 스크랩되었습니다.');
# 				}
# 			},
# 			error:function (xhr, ajaxOptions, thrownError) {
# 				//alert("사용중 오류가 발생 하였습니다. \n관리자에게 문의 하시기 바랍니다.");
# 		    }
# 		});
# 	}
#
# -->
# </script>
#
# <!--S: footer -->
# <div id="footer">
# <div class="wrapper">
# <p class="logo_bot"><img alt="한국언론진흥재단" height="51" src="/webcont/images/logo_bottom.png" width="184"/></p>
# <ul class="menuInfo">
# <li>
# <a alt="서비스 소개" href="/help/helpIntroduce.do">서비스 소개</a>
# <span class="bar">I</span>
# <a alt="BIG KINDS-Pro 소개" href="/help/helpIntroduceEx.do">BIG KINDS-Pro 소개</a>
# <span class="bar">I</span>
# <a alt="이메일 무단수집거부" href="/help/helpEmail.do">이메일 무단수집거부</a>
# </li>
# <li id="address">서울특별시 중구 세종대로 124<span class="bar">I</span> 대표 : 김병호<span class="bar">I</span> 사업자등록번호 : 104-82-11163<span class="bar">I</span> 대표전화 : 02-2001-7572~5</li>
# <li id="copy">EMAIL :<a href="mailto:bigkinds@kpf.or.kr">bigkinds@kpf.or.kr</a><span class="bar">I</span>
# 			COPYRIGHTⓒ 2015 KOREA PRESS FOUNDATION. ALL RIGHTS RESERVED.</li>
# </ul>
# <a href="http://wa.or.kr/waMark/status.asp" target="_blank" title="새창">
# <img alt="(사)한국장애인단체총연합회 한국웹접근성인증평가원 웹 접근성 우수사이트 인증마크(WA인증마크)" class="mark" height="65" src="/webcont/images/btm_wa_auth.gif" width="100"/>
# </a>
# </div>
# </div>
# <!--E: footer -->
# <!--S: Web Log -->
# <!-- <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-92165515-1', 'auto');
#   ga('send', 'pageview');
# </script>   -->
# <!--E: Web Log -->

# %%
a_tag_list = soup.select('.list dt a')
a_tag_list
# Out:
# [<a href="/search/totalSearchView.do?news_id=02100311.20171007090041001">
#
#  									[연휴에 다시 볼만한 영화 ‘노무현입니다’]우리가 사랑했던 노무현에 ..
#  								</a>,
#  <a href="/search/totalSearchView.do?news_id=02100311.20171007014527001">
#
#  									정미홍, 김빈 ‘관종’ 발언에 분노…“가만히 있는 사람 자꾸 건드려”
#  								</a>,
#  <a href="/search/totalSearchView.do?news_id=02100311.20171007004858001">
#
#  									내달부터 65세 이상 틀니 본인부담률 50%→30% 대폭 인하
#  								</a>,
#  <a href="/search/totalSearchView.do?news_id=04100078.20171007110326001">
#
#  									[미리보는 국감] 기재위, 소득주도성장면세점담뱃세 논란에 '후끈'
#  								</a>,
#  <a href="/search/totalSearchView.do?news_id=02100701.20171007110250001">
#
#  									되살아나는 부동산 시장… ‘주머니 속 카드’ 또 꺼내나
#  								</a>,
#  <a href="/search/totalSearchView.do?news_id=02100701.20171007110147001">
#
#  									초과이익환수제 부활까지 석달… 논란은 계속 중
#  								</a>,
#  <a href="/search/totalSearchView.do?news_id=01100611.20171007103120001">
#
#  									靑, 추석 막바지 北도발 가능성 예의주시… NSC 비상가동
#  								</a>,
#  <a href="/search/totalSearchView.do?news_id=08100401.20171007103003002">
#
#  									靑, 北 추가 도발 예의주시..."도발 징후는 아직"
#  								</a>,
#  <a href="/search/totalSearchView.do?news_id=01101001.20171007102836001">
#
#  									치매, 알면 이긴다…치매국가책임제 활용법
#  								</a>,
#  <a href="/search/totalSearchView.do?news_id=08100401.20171007102802001">
#
#  									靑 관람객 증가...지금 신청해도 내년 2월 가능
#  								</a>]

# %%
from urllib.parse import urljoin

for tag in a_tag_list:
    title = tag.text.strip()
    link = urljoin(result_url, tag['href'])
    print(title, link)
# Out:
# [연휴에 다시 볼만한 영화 ‘노무현입니다’]우리가 사랑했던 노무현에 .. http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007090041001
# 정미홍, 김빈 ‘관종’ 발언에 분노…“가만히 있는 사람 자꾸 건드려” http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007014527001
# 내달부터 65세 이상 틀니 본인부담률 50%→30% 대폭 인하 http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007004858001
# [미리보는 국감] 기재위, 소득주도성장면세점담뱃세 논란에 '후끈' http://211.43.216.33/search/totalSearchView.do?news_id=04100078.20171007110326001
# 되살아나는 부동산 시장… ‘주머니 속 카드’ 또 꺼내나 http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110250001
# 초과이익환수제 부활까지 석달… 논란은 계속 중 http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110147001
# 靑, 추석 막바지 北도발 가능성 예의주시… NSC 비상가동 http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20171007103120001
# 靑, 北 추가 도발 예의주시..."도발 징후는 아직" http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007103003002
# 치매, 알면 이긴다…치매국가책임제 활용법 http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007102836001
# 靑 관람객 증가...지금 신청해도 내년 2월 가능 http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007102802001

# %% [markdown]
# ### 하나의 데이터로 만들어 볼까?

# %%
article_list = soup.select('.list div')

scraped_data = {}

for article in article_list:
    title = article.select_one('dt a').text.strip()
    link = urljoin(result_url, article.select_one('dt a')['href'])
    discription = article.select_one('dd a').text

    made = article.select_one('.txt_blue11').text.strip().split()
    # print(made)
    newspaper = made[0]
    created_date = made[2]
    try:
        writer = made[4]
    except IndexError:
        writer = None
        
    # print(title, link, discription, newspaper, created_date, writer)
    
    items = {}
    items['title'] = title
    items['link'] = link
    items['discription'] = discription
    items['newspaper'] = newspaper
    items['created_date'] = created_date
    items['writer'] = writer

    scraped_data[link] = items

scraped_data
# Out:
# {'http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20171007103120001': {'created_date': '2017.10.07',
#   'discription': '청와대는 7일 북한이 추석연휴 막바지인 오는 10일 노동당 창건일을 전후해 미사일 등을 이용한 추가 도발 가능성이 있다고 보고 상황을 예의주시하고 있는 것으로 알려졌다. 청와..이와 관련해 정의용 청와대 국가안보실장은 지난 달 27일 청와대 상춘재에서 열린 문재인 대통령과 여야 4당 대표와의 만찬 회동에서 ',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20171007103120001',
#   'newspaper': '서울신문',
#   'title': '靑, 추석 막바지 北도발 가능성 예의주시… NSC 비상가동',
#   'writer': '문경근'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007102836001': {'created_date': '2017.10.07',
#   'discription': '올해 70살인 남성 장순원(가명)씨는 최근 조금 전 들은 이야기를 기억하지 못하는 일이 잦아졌다. 술자리가 끊이지 않았던 회사를 그만두고 시작한 사업은 스트레스가 많았다.. 정부는 문재인 대통령의 공약인 치매국가책임제를 실현하기 위해 오는 12월부터 전국 252곳 보건소에 치매안심센터를 설치하겠다고 밝혔다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007102836001',
#   'newspaper': '한겨레',
#   'title': '치매, 알면 이긴다…치매국가책임제 활용법',
#   'writer': None},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007004858001': {'created_date': '2017.10.07',
#   'discription': '내달부터 65세 이상 노인이 틀니 시술을 받을 때 내야 하는 본인부담금이 큰 폭으로 낮아진다.    6일 보건복지부에 따르면 11월부터 건강보험에 가입한 65세 이상 노인의 틀니 시술 본인 부담률을 현행 50%에..노인틀니 본인 부담 절감은 문재인 대통령의 대선 공약이자, 치과의사협회의 건의사항이기도 하다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007004858001',
#   'newspaper': '서울경제',
#   'title': '내달부터 65세 이상 틀니 본인부담률 50%→30% 대폭 인하',
#   'writer': '전종선'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007014527001': {'created_date': '2017.10.07',
#   'discription': '정미홍 전 아나운서가 더불어민주당 김빈 디지털대변인의 ‘관종’ 발언에 불편한 심경을 드러냈다.    정미홍은 7일 자신의 페이스북에 “김 빈이 누구죠? 더불당.. 한편 국민은 당신을 관종이라 부릅니다”라는 글과 함께 정미홍이 문재인 대통령의 아내 문정숙 여사에 막말을 쏟아냈다는 내용이 담긴 기사를 링크했다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007014527001',
#   'newspaper': '서울경제',
#   'title': '정미홍, 김빈 ‘관종’ 발언에 분노…“가만히 있는 사람 자꾸 건드려”',
#   'writer': '전종선'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007090041001': {'created_date': '2017.10.07',
#   'discription': '“김근태 의원은 존경스러운 분이었고, 노무현 대통령은 사랑스러운 분이었어요. 김근태 의원이 따라 하고 싶은 분이었다면, 노무현 대통령은 뭔가 해주고 싶은 분이었어요.”    유시민 작가는 다큐멘터리.. 또 문재인 현 대통령, 안희정 충남도지사 등 정치인부터 부림사건의 피해자, 강원국 전 대통령 연설비서관, ',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007090041001',
#   'newspaper': '서울경제',
#   'title': '[연휴에 다시 볼만한 영화 ‘노무현입니다’]우리가 사랑했던 노무현에 ..',
#   'writer': '연승'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110147001': {'created_date': '2017.10.07',
#   'discription': '-재건축 과열 잡으려 도입  -미실현 이익 과세 등 논란  -“부과시점 조절 등으로 개선해야”      [헤럴드경제=김성훈 기자] 재건축 초과이익환수제 시행이 석달 앞으로 다가왔다. 정부는 예정대로 이 제도를 시행하겠다고 공언한 상태지만,..문재인 정부는 초과이익환수제를 시행하겠다고 몇차례 확언한 바 있다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110147001',
#   'newspaper': '헤럴드경제',
#   'title': '초과이익환수제 부활까지 석달… 논란은 계속 중',
#   'writer': '김성훈'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110250001': {'created_date': '2017.10.07',
#   'discription': '[헤럴드경제=김성훈 기자] ‘8.2 부동산 대책’이 나온지 두 달이 다 돼 가면서 얼어붙었던 부동산 시장이 조금씩 살아나고 있다. 문재인 대통령이 “주머니 속에 있다”고 했던 추가 부동산 대책을 꺼낼지 주목된다.    한국감정원에 따르면, 지난 9월25일 기준 서울 아파트 값은 1주일 동안 0.08% 상..',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110250001',
#   'newspaper': '헤럴드경제',
#   'title': '되살아나는 부동산 시장… ‘주머니 속 카드’ 또 꺼내나',
#   'writer': '김성훈'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=04100078.20171007110326001': {'created_date': '2017.10.07',
#   'discription': '[뉴스핌=이윤애 기자] 오는 12일부터 시작되는 국회 기획재정위원회 국정감사에서 여당은 박근혜 정부의 적폐를, 야당은 문재인 정부의 소득주도성장의 문제점을 집중 파헤치겠다고 벼르고 있다.      반면 야당은 문재인 정부의 소득주도성장을 집중 공격할 계획이다. 문재인 대통령이 지난달 26일 국무회의에서 ',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=04100078.20171007110326001',
#   'newspaper': '뉴스핌',
#   'title': "[미리보는 국감] 기재위, 소득주도성장면세점담뱃세 논란에 '후끈'",
#   'writer': '이윤애'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007102802001': {'created_date': '2017.10.07',
#   'discription': '문재인 정부 출범 후 시민들의 청와대 관람 신청이 크게 늘어 지금 신청해도 내년 2월에야 볼 수 있는 것으로 나타났습니다.  청와대 경내는 매주 화요일부터 금요일, 둘째·넷째 주 토요일에 관람할 수 있는..문재인 정부가 출범한 5월부터 9월까지는 월평균 2만2천백여 명으로 관람객 수가 3.35배 늘었습니다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007102802001',
#   'newspaper': 'YTN',
#   'title': '靑 관람객 증가...지금 신청해도 내년 2월 가능',
#   'writer': None},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007103003002': {'created_date': '2017.10.07',
#   'discription': '청와대는 오는 10일, 노동당 창건일을 전후로 북한이 추가 도발할 가능성이 있다고 보고 상황을 예의주시하고 있습니다.  청와대 관계자는 아..앞서 정의용 국가안보실장은 지난달 27일, 문재인 대통령과 여야 4당 대표 만찬 회동에서 10월 10일이나 18일을 전후해 북한의 추가 도발이 예상된다고 보고했습니다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007103003002',
#   'newspaper': 'YTN',
#   'title': '靑, 北 추가 도발 예의주시..."도발 징후는 아직"',
#   'writer': None}}

# %% [markdown]
# #### 코드를 다시 정리해보면,

# %%
article_list = soup.select('.list div')

scraped_data = {}

for article in article_list:
    items = {}
    items['title'] = article.select_one('dt a').text.strip()
    items['link'] = urljoin(result_url, article.select_one('dt a')['href'])
    items['discription'] = article.select_one('dd a').text

    made = article.select_one('.txt_blue11').text.strip().split()
    
    items['newspaper'] = made[0]
    items['created_date'] = made[2]
    try:
        items['writer'] = made[4]
    except IndexError:
        items['writer'] = None
            
    scraped_data[items['link']] = items

scraped_data
# Out:
# {'http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20171007103120001': {'created_date': '2017.10.07',
#   'discription': '청와대는 7일 북한이 추석연휴 막바지인 오는 10일 노동당 창건일을 전후해 미사일 등을 이용한 추가 도발 가능성이 있다고 보고 상황을 예의주시하고 있는 것으로 알려졌다. 청와..이와 관련해 정의용 청와대 국가안보실장은 지난 달 27일 청와대 상춘재에서 열린 문재인 대통령과 여야 4당 대표와의 만찬 회동에서 ',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20171007103120001',
#   'newspaper': '서울신문',
#   'title': '靑, 추석 막바지 北도발 가능성 예의주시… NSC 비상가동',
#   'writer': '문경근'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007102836001': {'created_date': '2017.10.07',
#   'discription': '올해 70살인 남성 장순원(가명)씨는 최근 조금 전 들은 이야기를 기억하지 못하는 일이 잦아졌다. 술자리가 끊이지 않았던 회사를 그만두고 시작한 사업은 스트레스가 많았다.. 정부는 문재인 대통령의 공약인 치매국가책임제를 실현하기 위해 오는 12월부터 전국 252곳 보건소에 치매안심센터를 설치하겠다고 밝혔다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007102836001',
#   'newspaper': '한겨레',
#   'title': '치매, 알면 이긴다…치매국가책임제 활용법',
#   'writer': None},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007004858001': {'created_date': '2017.10.07',
#   'discription': '내달부터 65세 이상 노인이 틀니 시술을 받을 때 내야 하는 본인부담금이 큰 폭으로 낮아진다.    6일 보건복지부에 따르면 11월부터 건강보험에 가입한 65세 이상 노인의 틀니 시술 본인 부담률을 현행 50%에..노인틀니 본인 부담 절감은 문재인 대통령의 대선 공약이자, 치과의사협회의 건의사항이기도 하다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007004858001',
#   'newspaper': '서울경제',
#   'title': '내달부터 65세 이상 틀니 본인부담률 50%→30% 대폭 인하',
#   'writer': '전종선'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007014527001': {'created_date': '2017.10.07',
#   'discription': '정미홍 전 아나운서가 더불어민주당 김빈 디지털대변인의 ‘관종’ 발언에 불편한 심경을 드러냈다.    정미홍은 7일 자신의 페이스북에 “김 빈이 누구죠? 더불당.. 한편 국민은 당신을 관종이라 부릅니다”라는 글과 함께 정미홍이 문재인 대통령의 아내 문정숙 여사에 막말을 쏟아냈다는 내용이 담긴 기사를 링크했다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007014527001',
#   'newspaper': '서울경제',
#   'title': '정미홍, 김빈 ‘관종’ 발언에 분노…“가만히 있는 사람 자꾸 건드려”',
#   'writer': '전종선'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007090041001': {'created_date': '2017.10.07',
#   'discription': '“김근태 의원은 존경스러운 분이었고, 노무현 대통령은 사랑스러운 분이었어요. 김근태 의원이 따라 하고 싶은 분이었다면, 노무현 대통령은 뭔가 해주고 싶은 분이었어요.”    유시민 작가는 다큐멘터리.. 또 문재인 현 대통령, 안희정 충남도지사 등 정치인부터 부림사건의 피해자, 강원국 전 대통령 연설비서관, ',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007090041001',
#   'newspaper': '서울경제',
#   'title': '[연휴에 다시 볼만한 영화 ‘노무현입니다’]우리가 사랑했던 노무현에 ..',
#   'writer': '연승'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110147001': {'created_date': '2017.10.07',
#   'discription': '-재건축 과열 잡으려 도입  -미실현 이익 과세 등 논란  -“부과시점 조절 등으로 개선해야”      [헤럴드경제=김성훈 기자] 재건축 초과이익환수제 시행이 석달 앞으로 다가왔다. 정부는 예정대로 이 제도를 시행하겠다고 공언한 상태지만,..문재인 정부는 초과이익환수제를 시행하겠다고 몇차례 확언한 바 있다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110147001',
#   'newspaper': '헤럴드경제',
#   'title': '초과이익환수제 부활까지 석달… 논란은 계속 중',
#   'writer': '김성훈'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110250001': {'created_date': '2017.10.07',
#   'discription': '[헤럴드경제=김성훈 기자] ‘8.2 부동산 대책’이 나온지 두 달이 다 돼 가면서 얼어붙었던 부동산 시장이 조금씩 살아나고 있다. 문재인 대통령이 “주머니 속에 있다”고 했던 추가 부동산 대책을 꺼낼지 주목된다.    한국감정원에 따르면, 지난 9월25일 기준 서울 아파트 값은 1주일 동안 0.08% 상..',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110250001',
#   'newspaper': '헤럴드경제',
#   'title': '되살아나는 부동산 시장… ‘주머니 속 카드’ 또 꺼내나',
#   'writer': '김성훈'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=04100078.20171007110326001': {'created_date': '2017.10.07',
#   'discription': '[뉴스핌=이윤애 기자] 오는 12일부터 시작되는 국회 기획재정위원회 국정감사에서 여당은 박근혜 정부의 적폐를, 야당은 문재인 정부의 소득주도성장의 문제점을 집중 파헤치겠다고 벼르고 있다.      반면 야당은 문재인 정부의 소득주도성장을 집중 공격할 계획이다. 문재인 대통령이 지난달 26일 국무회의에서 ',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=04100078.20171007110326001',
#   'newspaper': '뉴스핌',
#   'title': "[미리보는 국감] 기재위, 소득주도성장면세점담뱃세 논란에 '후끈'",
#   'writer': '이윤애'},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007102802001': {'created_date': '2017.10.07',
#   'discription': '문재인 정부 출범 후 시민들의 청와대 관람 신청이 크게 늘어 지금 신청해도 내년 2월에야 볼 수 있는 것으로 나타났습니다.  청와대 경내는 매주 화요일부터 금요일, 둘째·넷째 주 토요일에 관람할 수 있는..문재인 정부가 출범한 5월부터 9월까지는 월평균 2만2천백여 명으로 관람객 수가 3.35배 늘었습니다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007102802001',
#   'newspaper': 'YTN',
#   'title': '靑 관람객 증가...지금 신청해도 내년 2월 가능',
#   'writer': None},
#  'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007103003002': {'created_date': '2017.10.07',
#   'discription': '청와대는 오는 10일, 노동당 창건일을 전후로 북한이 추가 도발할 가능성이 있다고 보고 상황을 예의주시하고 있습니다.  청와대 관계자는 아..앞서 정의용 국가안보실장은 지난달 27일, 문재인 대통령과 여야 4당 대표 만찬 회동에서 10월 10일이나 18일을 전후해 북한의 추가 도발이 예상된다고 보고했습니다.',
#   'link': 'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007103003002',
#   'newspaper': 'YTN',
#   'title': '靑, 北 추가 도발 예의주시..."도발 징후는 아직"',
#   'writer': None}}

# %% [markdown]
# #### 출력해볼까?

# %%
for key, value_dict in scraped_data.items():
    for key, value in value_dict.items():
        print(key.title() + ': ' + str(value))
    print('\n')
# Out:
# Title: [연휴에 다시 볼만한 영화 ‘노무현입니다’]우리가 사랑했던 노무현에 ..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007090041001
# Discription: “김근태 의원은 존경스러운 분이었고, 노무현 대통령은 사랑스러운 분이었어요. 김근태 의원이 따라 하고 싶은 분이었다면, 노무현 대통령은 뭔가 해주고 싶은 분이었어요.”    유시민 작가는 다큐멘터리.. 또 문재인 현 대통령, 안희정 충남도지사 등 정치인부터 부림사건의 피해자, 강원국 전 대통령 연설비서관,
# Newspaper: 서울경제
# Created_Date: 2017.10.07
# Writer: 연승
#
#
# Title: 정미홍, 김빈 ‘관종’ 발언에 분노…“가만히 있는 사람 자꾸 건드려”
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007014527001
# Discription: 정미홍 전 아나운서가 더불어민주당 김빈 디지털대변인의 ‘관종’ 발언에 불편한 심경을 드러냈다.    정미홍은 7일 자신의 페이스북에 “김 빈이 누구죠? 더불당.. 한편 국민은 당신을 관종이라 부릅니다”라는 글과 함께 정미홍이 문재인 대통령의 아내 문정숙 여사에 막말을 쏟아냈다는 내용이 담긴 기사를 링크했다.
# Newspaper: 서울경제
# Created_Date: 2017.10.07
# Writer: 전종선
#
#
# Title: 내달부터 65세 이상 틀니 본인부담률 50%→30% 대폭 인하
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007004858001
# Discription: 내달부터 65세 이상 노인이 틀니 시술을 받을 때 내야 하는 본인부담금이 큰 폭으로 낮아진다.    6일 보건복지부에 따르면 11월부터 건강보험에 가입한 65세 이상 노인의 틀니 시술 본인 부담률을 현행 50%에..노인틀니 본인 부담 절감은 문재인 대통령의 대선 공약이자, 치과의사협회의 건의사항이기도 하다.
# Newspaper: 서울경제
# Created_Date: 2017.10.07
# Writer: 전종선
#
#
# Title: [미리보는 국감] 기재위, 소득주도성장면세점담뱃세 논란에 '후끈'
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=04100078.20171007110326001
# Discription: [뉴스핌=이윤애 기자] 오는 12일부터 시작되는 국회 기획재정위원회 국정감사에서 여당은 박근혜 정부의 적폐를, 야당은 문재인 정부의 소득주도성장의 문제점을 집중 파헤치겠다고 벼르고 있다.      반면 야당은 문재인 정부의 소득주도성장을 집중 공격할 계획이다. 문재인 대통령이 지난달 26일 국무회의에서
# Newspaper: 뉴스핌
# Created_Date: 2017.10.07
# Writer: 이윤애
#
#
# Title: 되살아나는 부동산 시장… ‘주머니 속 카드’ 또 꺼내나
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110250001
# Discription: [헤럴드경제=김성훈 기자] ‘8.2 부동산 대책’이 나온지 두 달이 다 돼 가면서 얼어붙었던 부동산 시장이 조금씩 살아나고 있다. 문재인 대통령이 “주머니 속에 있다”고 했던 추가 부동산 대책을 꺼낼지 주목된다.    한국감정원에 따르면, 지난 9월25일 기준 서울 아파트 값은 1주일 동안 0.08% 상..
# Newspaper: 헤럴드경제
# Created_Date: 2017.10.07
# Writer: 김성훈
#
#
# Title: 초과이익환수제 부활까지 석달… 논란은 계속 중
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110147001
# Discription: -재건축 과열 잡으려 도입  -미실현 이익 과세 등 논란  -“부과시점 조절 등으로 개선해야”      [헤럴드경제=김성훈 기자] 재건축 초과이익환수제 시행이 석달 앞으로 다가왔다. 정부는 예정대로 이 제도를 시행하겠다고 공언한 상태지만,..문재인 정부는 초과이익환수제를 시행하겠다고 몇차례 확언한 바 있다.
# Newspaper: 헤럴드경제
# Created_Date: 2017.10.07
# Writer: 김성훈
#
#
# Title: 靑, 추석 막바지 北도발 가능성 예의주시… NSC 비상가동
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20171007103120001
# Discription: 청와대는 7일 북한이 추석연휴 막바지인 오는 10일 노동당 창건일을 전후해 미사일 등을 이용한 추가 도발 가능성이 있다고 보고 상황을 예의주시하고 있는 것으로 알려졌다. 청와..이와 관련해 정의용 청와대 국가안보실장은 지난 달 27일 청와대 상춘재에서 열린 문재인 대통령과 여야 4당 대표와의 만찬 회동에서
# Newspaper: 서울신문
# Created_Date: 2017.10.07
# Writer: 문경근
#
#
# Title: 靑, 北 추가 도발 예의주시..."도발 징후는 아직"
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007103003002
# Discription: 청와대는 오는 10일, 노동당 창건일을 전후로 북한이 추가 도발할 가능성이 있다고 보고 상황을 예의주시하고 있습니다.  청와대 관계자는 아..앞서 정의용 국가안보실장은 지난달 27일, 문재인 대통령과 여야 4당 대표 만찬 회동에서 10월 10일이나 18일을 전후해 북한의 추가 도발이 예상된다고 보고했습니다.
# Newspaper: YTN
# Created_Date: 2017.10.07
# Writer: None
#
#
# Title: 치매, 알면 이긴다…치매국가책임제 활용법
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007102836001
# Discription: 올해 70살인 남성 장순원(가명)씨는 최근 조금 전 들은 이야기를 기억하지 못하는 일이 잦아졌다. 술자리가 끊이지 않았던 회사를 그만두고 시작한 사업은 스트레스가 많았다.. 정부는 문재인 대통령의 공약인 치매국가책임제를 실현하기 위해 오는 12월부터 전국 252곳 보건소에 치매안심센터를 설치하겠다고 밝혔다.
# Newspaper: 한겨레
# Created_Date: 2017.10.07
# Writer: None
#
#
# Title: 靑 관람객 증가...지금 신청해도 내년 2월 가능
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007102802001
# Discription: 문재인 정부 출범 후 시민들의 청와대 관람 신청이 크게 늘어 지금 신청해도 내년 2월에야 볼 수 있는 것으로 나타났습니다.  청와대 경내는 매주 화요일부터 금요일, 둘째·넷째 주 토요일에 관람할 수 있는..문재인 정부가 출범한 5월부터 9월까지는 월평균 2만2천백여 명으로 관람객 수가 3.35배 늘었습니다.
# Newspaper: YTN
# Created_Date: 2017.10.07
# Writer: None

# %% [markdown]
# ### 근데 생각해보니까 검색 결과가 여러 페이지잖아?

# %% [raw]
# # 2페이지 Form Data
#
# listPage:2
# listCount:10
# keyword:문재인
# orderByOption:desc
# fromDate:
# toDate:
# provider_code:
# provider_name:
# category_code:
# category_name:
# larm_incident_category_path:
# larm_incident_category_nm:
# search_field:_search
# search_method:0
# realKeyword:
# keywordType:N
# byline:

# %%
from collections import OrderedDict
import requests
from bs4 import BeautifulSoup

scraped_data = {}

for page in range(1, 3):
    lines = '''listPage:{}
listCount:10
keyword:문재인
orderByOption:desc
fromDate:
toDate:
provider_code:
provider_name:
category_code:
category_name:
larm_incident_category_path:
larm_incident_category_nm:
search_field:_search
search_method:0
realKeyword:
keywordType:N
byline:'''.format(page).splitlines()

    data = {}
    for line in lines:
        key, value = line.split(':', 1)
        if value == 'null':
            value = None
        data[key] = value
    
#     print(data)
    
    result_url = 'http://211.43.216.33/search/totalSearchList.do'
    r = requests.post(result_url, data=data)
    print(str(page) + ' page', r)
    soup = BeautifulSoup(r.text, 'html.parser')

    article_list = soup.select('.list div')

    for article in article_list:
        items = OrderedDict()
        items['title'] = article.select_one('dt a').text.strip()
        items['link'] = urljoin(result_url, article.select_one('dt a')['href'])
        items['discription'] = article.select_one('dd a').text

        made = article.select_one('.txt_blue11').text.strip().split()

        items['newspaper'] = made[0]
        items['created_date'] = made[2]
        try:
            items['writer'] = made[4]
        except IndexError:
            items['writer'] = None

        scraped_data[items['link']] = items

scraped_data
# Out:
# 1 page <Response [200]>
# 2 page <Response [200]>
# {'http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20171007103120001': OrderedDict([('title',
#                '靑, 추석 막바지 北도발 가능성 예의주시… NSC 비상가동'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20171007103120001'),
#               ('discription',
#                '청와대는 7일 북한이 추석연휴 막바지인 오는 10일 노동당 창건일을 전후해 미사일 등을 이용한 추가 도발 가능성이 있다고 보고 상황을 예의주시하고 있는 것으로 알려졌다. 청와..이와 관련해 정의용 청와대 국가안보실장은 지난 달 27일 청와대 상춘재에서 열린 문재인 대통령과 여야 4당 대표와의 만찬 회동에서 '),
#               ('newspaper', '서울신문'),
#               ('created_date', '2017.10.07'),
#               ('writer', '문경근')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20171007100752001': OrderedDict([('title',
#                '청와대 관람신청 폭증…내년 2월에나 갈 수 있다'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20171007100752001'),
#               ('discription',
#                '문재인 대통령 트위터 캡처.  지금 당장 신청해도 내년 2월에나 관람할 수 있을 만큼 청와대 관람을 원하는 사람이 많은 것으로 나타났다.    7일 청와대에 따르면 새 정부가 출범한 지난 5월부터 9월까지 월평균 청와대 관람객 수는 2만2000여명이다.    박근혜 전 대통령 탄핵 기간을 포함한 올 1월..'),
#               ('newspaper', '세계일보'),
#               ('created_date', '2017.10.07'),
#               ('writer', '김동환')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20171007101058001': OrderedDict([('title',
#                '정미홍 수위 높은 발언 계속…"관종? 관심받는 거 싫어해"'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20171007101058001'),
#               ('discription',
#                '문재인 대통령 부인 김정숙 여사를 공개적으로 비난해 논란의 중심에 선 KBS 아나운서 출신 정미홍이 계속해 수위 높은 발언을 이어가고 있다.    지난 1일 정미홍은 자신의 페이스북에 김정숙 여사를 향해 "사치부릴 시간에 영어 공부나 좀 하고, 운동해서 살이나 좀 빼시길"이라는 글을 남겼다.    해당 ..'),
#               ('newspaper', '세계일보'),
#               ('created_date', '2017.10.07'),
#               ('writer', '한누리')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007094809001': OrderedDict([('title',
#                '심블리 심상정, 리베로 노회찬, 꿈나무 이정미의 소명'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007094809001'),
#               ('discription',
#                ' 안경환·조대엽·박성진 등 문재인 정부 장관 후보자들의 낙마를 주장했고 실현됐다는 점에서 ..문재인 후보와 박빙의 승부를 펼친 것이다. 노회찬 원내대표는 문재인 정권과의 적절한 관계 설정도 고민하고 있다...문재인 정부를 더..‘촛불정권’을 표방하는 문재인 정부에서 정의당의 활로를 찾기 위한 나름의 고민인 셈이다.'),
#               ('newspaper', '한겨레'),
#               ('created_date', '2017.10.07'),
#               ('writer', '김태규')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007095833002': OrderedDict([('title',
#                '‘쉬운 해고’ 지침 폐기는 정부의 시장 개입일까'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007095833002'),
#               ('discription',
#                '경제학자들의 눈길을 빠르게 사로잡는 단어를 꼽으라면 ‘시장 개입’입니다. 균형이라는 개념을 통해서 세상을 바라보는 경제학자들은 외부적 개입에 즉각적으.. 박근혜 정부의 창조경제에 대해서 할 말이 없던 학자들이 문재인 정부의 경제정책에 대해서는 칼럼을 쓰기 시작하고, 현실 참여적 연구자로 거듭날 이유입니다. '),
#               ('newspaper', '한겨레'),
#               ('created_date', '2017.10.07'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007100854001': OrderedDict([('title',
#                '‘홍준표 키즈’는 태풍일까 미풍일까'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007100854001'),
#               ('discription',
#                '‘홍준표 키즈’는 내년 지방선거에서 과연 ....문재인 대통령의 고향인 경남은 두 거대정당의 절대 물러설 수 없는 전쟁터가 될 것이 분명하다. ‘문재인 대통령의 복심’으로 통하는 민주당 김경수(51·김해을) 의원의 경남도지사 선거 출마 필요성이 제기되고 있는데, 김 의원 본인은 명확한 뜻을 밝히지 않고 있다. '),
#               ('newspaper', '한겨레'),
#               ('created_date', '2017.10.07'),
#               ('writer', '최상원')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007101817001': OrderedDict([('title',
#                '‘적폐청산’이라는데 왜 자꾸 ‘정치보복’ 논란이 일어날까'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007101817001'),
#               ('discription',
#                ' 따라서 이 부분은 문재인 대통령도 어떻게 해 볼 도리가 없습니다.  이 대목에서 문재인 대통령과 청와대 참모들의 지혜가 필요합니다. 문재인 대통령에게 실제로 이상주의자의 면모가 있는 것은 사실입니다...문재인 대통령이 이상주의자라는 진단에 저는.. 문재인 대통령은 대선 직후 노무현 전 대통령 추도식에 참석해 '),
#               ('newspaper', '한겨레'),
#               ('created_date', '2017.10.07'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007102836001': OrderedDict([('title',
#                '치매, 노화와는 다르다…치매국가책임제 활용법'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007102836001'),
#               ('discription',
#                '올해 70살인 남성 장순원(가명)씨는 최근 조금 전 들은 이야기를 기억하지 못하는 일이 잦아졌다. 술자리가 끊이지 않았던 회사를 그만두고 시작한 사업은 스트레스가 많았다.. 정부는 문재인 대통령의 공약인 치매국가책임제를 실현하기 위해 오는 12월부터 전국 252곳 보건소에 치매안심센터를 설치하겠다고 밝혔다.'),
#               ('newspaper', '한겨레'),
#               ('created_date', '2017.10.07'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01200201.20171007091854001': OrderedDict([('title',
#                "靑관람 대기줄 '끝이 안 보여'…지금 신청해도 내년 2월 가능"),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01200201.20171007091854001'),
#               ('discription',
#                '문재인 정부 출범 이후 청와대 관람 신청이 크게 늘어나 지금 당장 신청해도 사실상 내년 2월에야 청와대 관람을 할 수 있는 것으로 나타났다.  청와대에 따르면 새 정부가 출범한 5월부터 9월까지(8월은 혹서기 휴관으로 제외) 월평균 청와대 관람객 수는 2만2천118명에 달했다.  반면, 박근혜 전 대통령..'),
#               ('newspaper', '경인일보'),
#               ('created_date', '2017.10.07'),
#               ('writer', '박주우')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007004858001': OrderedDict([('title',
#                '내달부터 65세 이상 틀니 본인부담률 50%→30% 대폭 인하'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007004858001'),
#               ('discription',
#                '내달부터 65세 이상 노인이 틀니 시술을 받을 때 내야 하는 본인부담금이 큰 폭으로 낮아진다.    6일 보건복지부에 따르면 11월부터 건강보험에 가입한 65세 이상 노인의 틀니 시술 본인 부담률을 현행 50%에..노인틀니 본인 부담 절감은 문재인 대통령의 대선 공약이자, 치과의사협회의 건의사항이기도 하다.'),
#               ('newspaper', '서울경제'),
#               ('created_date', '2017.10.07'),
#               ('writer', '전종선')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007014527001': OrderedDict([('title',
#                '정미홍, 김빈 ‘관종’ 발언에 분노…“가만히 있는 사람 자꾸 건드려”'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007014527001'),
#               ('discription',
#                '정미홍 전 아나운서가 더불어민주당 김빈 디지털대변인의 ‘관종’ 발언에 불편한 심경을 드러냈다.    정미홍은 7일 자신의 페이스북에 “김 빈이 누구죠? 더불당.. 한편 국민은 당신을 관종이라 부릅니다”라는 글과 함께 정미홍이 문재인 대통령의 아내 문정숙 여사에 막말을 쏟아냈다는 내용이 담긴 기사를 링크했다.'),
#               ('newspaper', '서울경제'),
#               ('created_date', '2017.10.07'),
#               ('writer', '전종선')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007090041001': OrderedDict([('title',
#                '[연휴에 다시 볼만한 영화 ‘노무현입니다’]우리가 사랑했던 노무현에 ..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007090041001'),
#               ('discription',
#                '“김근태 의원은 존경스러운 분이었고, 노무현 대통령은 사랑스러운 분이었어요. 김근태 의원이 따라 하고 싶은 분이었다면, 노무현 대통령은 뭔가 해주고 싶은 분이었어요.”    유시민 작가는 다큐멘터리.. 또 문재인 현 대통령, 안희정 충남도지사 등 정치인부터 부림사건의 피해자, 강원국 전 대통령 연설비서관, '),
#               ('newspaper', '서울경제'),
#               ('created_date', '2017.10.07'),
#               ('writer', '연승')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100601.20171007100125001': OrderedDict([('title',
#                "'정권 초반 지방선거는 여당 승리' 공식, 내년에도 통할까"),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100601.20171007100125001'),
#               ('discription',
#                '제7회 지방선거(2018년 6월13일)가 8개월 앞으로 다가왔다. 이번 지방선거는 시 ·도지사 등 풀뿌리 권력을 선출한다는 의미 외에 문재인 정부 출범 후  처음 치러지는 전국 단위 선거라는 점에서 정치적 의미가 크다. 여당이 승리하 면 문재인 정부는 국정 운영에 더욱 가속도를 낼 수 있다. 반면 야당이..'),
#               ('newspaper', '한국경제'),
#               ('created_date', '2017.10.07'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007095423001': OrderedDict([('title',
#                '靑, 추석 막바지 北도발 가능성 예의주시…“아직 징후 포착안돼”'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007095423001'),
#               ('discription',
#                '[헤럴드경제] 청와대는 북한이 10일 노동당 창건일을 전후해 추가 도발 가능성이 있다고 보고, 상황을 예의주시하고 있다. 정의용 청와대 국가안보실장은 지난 달 27일 청와대 상춘재에서 열린 문재인 대통령과 여야 4당 대표와의 만찬 회동에서 “10월 10일 혹은 18일을 전후로 북한의 추가도발이 예상된다”..'),
#               ('newspaper', '헤럴드경제'),
#               ('created_date', '2017.10.07'),
#               ('writer', '박병국')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110147001': OrderedDict([('title',
#                '초과이익환수제 부활까지 석달… 논란은 계속 중'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110147001'),
#               ('discription',
#                '-재건축 과열 잡으려 도입  -미실현 이익 과세 등 논란  -“부과시점 조절 등으로 개선해야”      [헤럴드경제=김성훈 기자] 재건축 초과이익환수제 시행이 석달 앞으로 다가왔다. 정부는 예정대로 이 제도를 시행하겠다고 공언한 상태지만,..문재인 정부는 초과이익환수제를 시행하겠다고 몇차례 확언한 바 있다.'),
#               ('newspaper', '헤럴드경제'),
#               ('created_date', '2017.10.07'),
#               ('writer', '김성훈')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110250001': OrderedDict([('title',
#                '되살아나는 부동산 시장… ‘주머니 속 카드’ 또 꺼내나'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110250001'),
#               ('discription',
#                '[헤럴드경제=김성훈 기자] ‘8.2 부동산 대책’이 나온지 두 달이 다 돼 가면서 얼어붙었던 부동산 시장이 조금씩 살아나고 있다. 문재인 대통령이 “주머니 속에 있다”고 했던 추가 부동산 대책을 꺼낼지 주목된다.    한국감정원에 따르면, 지난 9월25일 기준 서울 아파트 값은 1주일 동안 0.08% 상..'),
#               ('newspaper', '헤럴드경제'),
#               ('created_date', '2017.10.07'),
#               ('writer', '김성훈')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=04100078.20171007110326001': OrderedDict([('title',
#                "[미리보는 국감] 기재위, 소득주도성장면세점담뱃세 논란에 '후끈'"),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=04100078.20171007110326001'),
#               ('discription',
#                '[뉴스핌=이윤애 기자] 오는 12일부터 시작되는 국회 기획재정위원회 국정감사에서 여당은 박근혜 정부의 적폐를, 야당은 문재인 정부의 소득주도성장의 문제점을 집중 파헤치겠다고 벼르고 있다.      반면 야당은 문재인 정부의 소득주도성장을 집중 공격할 계획이다. 문재인 대통령이 지난달 26일 국무회의에서 '),
#               ('newspaper', '뉴스핌'),
#               ('created_date', '2017.10.07'),
#               ('writer', '이윤애')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007094602001': OrderedDict([('title',
#                '미리 보는 호찌민-경주 세계문화엑스포'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007094602001'),
#               ('discription',
#                "[앵커] 오는 11월 베트남에서는 '호찌민-경주세계문화엑스포'가 열립니다.  캄보디아 앙코르와트, 터키 이스탄불에 이어 해외에서 열리는 세 번째 경주 엑스포인데요.  23일 동안 우리 문화를 알리는 수준 높고 다..문재인 대통령을 비롯한 해외 각국 주요 인사들이 개막식에 참석하기를 내심 기대하고 있습니다. "),
#               ('newspaper', 'YTN'),
#               ('created_date', '2017.10.07'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007102802001': OrderedDict([('title',
#                '靑 관람객 증가...지금 신청해도 내년 2월 가능'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007102802001'),
#               ('discription',
#                '문재인 정부 출범 후 시민들의 청와대 관람 신청이 크게 늘어 지금 신청해도 내년 2월에야 볼 수 있는 것으로 나타났습니다.  청와대 경내는 매주 화요일부터 금요일, 둘째·넷째 주 토요일에 관람할 수 있는..문재인 정부가 출범한 5월부터 9월까지는 월평균 2만2천백여 명으로 관람객 수가 3.35배 늘었습니다.'),
#               ('newspaper', 'YTN'),
#               ('created_date', '2017.10.07'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007103003002': OrderedDict([('title',
#                '靑, 北 추가 도발 예의주시..."도발 징후는 아직"'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007103003002'),
#               ('discription',
#                '청와대는 오는 10일, 노동당 창건일을 전후로 북한이 추가 도발할 가능성이 있다고 보고 상황을 예의주시하고 있습니다.  청와대 관계자는 아..앞서 정의용 국가안보실장은 지난달 27일, 문재인 대통령과 여야 4당 대표 만찬 회동에서 10월 10일이나 18일을 전후해 북한의 추가 도발이 예상된다고 보고했습니다.'),
#               ('newspaper', 'YTN'),
#               ('created_date', '2017.10.07'),
#               ('writer', None)])}

# %%
len(scraped_data)
# Out:
# 20

# %%
for key, value_dict in scraped_data.items():
    for key, value in value_dict.items():
        print(key.title() + ': ' + str(value))
    print('\n')
# Out:
# Title: [연휴에 다시 볼만한 영화 ‘노무현입니다’]우리가 사랑했던 노무현에 ..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007090041001
# Discription: “김근태 의원은 존경스러운 분이었고, 노무현 대통령은 사랑스러운 분이었어요. 김근태 의원이 따라 하고 싶은 분이었다면, 노무현 대통령은 뭔가 해주고 싶은 분이었어요.”    유시민 작가는 다큐멘터리.. 또 문재인 현 대통령, 안희정 충남도지사 등 정치인부터 부림사건의 피해자, 강원국 전 대통령 연설비서관,
# Newspaper: 서울경제
# Created_Date: 2017.10.07
# Writer: 연승
#
#
# Title: 정미홍, 김빈 ‘관종’ 발언에 분노…“가만히 있는 사람 자꾸 건드려”
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007014527001
# Discription: 정미홍 전 아나운서가 더불어민주당 김빈 디지털대변인의 ‘관종’ 발언에 불편한 심경을 드러냈다.    정미홍은 7일 자신의 페이스북에 “김 빈이 누구죠? 더불당.. 한편 국민은 당신을 관종이라 부릅니다”라는 글과 함께 정미홍이 문재인 대통령의 아내 문정숙 여사에 막말을 쏟아냈다는 내용이 담긴 기사를 링크했다.
# Newspaper: 서울경제
# Created_Date: 2017.10.07
# Writer: 전종선
#
#
# Title: 내달부터 65세 이상 틀니 본인부담률 50%→30% 대폭 인하
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20171007004858001
# Discription: 내달부터 65세 이상 노인이 틀니 시술을 받을 때 내야 하는 본인부담금이 큰 폭으로 낮아진다.    6일 보건복지부에 따르면 11월부터 건강보험에 가입한 65세 이상 노인의 틀니 시술 본인 부담률을 현행 50%에..노인틀니 본인 부담 절감은 문재인 대통령의 대선 공약이자, 치과의사협회의 건의사항이기도 하다.
# Newspaper: 서울경제
# Created_Date: 2017.10.07
# Writer: 전종선
#
#
# Title: [미리보는 국감] 기재위, 소득주도성장면세점담뱃세 논란에 '후끈'
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=04100078.20171007110326001
# Discription: [뉴스핌=이윤애 기자] 오는 12일부터 시작되는 국회 기획재정위원회 국정감사에서 여당은 박근혜 정부의 적폐를, 야당은 문재인 정부의 소득주도성장의 문제점을 집중 파헤치겠다고 벼르고 있다.      반면 야당은 문재인 정부의 소득주도성장을 집중 공격할 계획이다. 문재인 대통령이 지난달 26일 국무회의에서
# Newspaper: 뉴스핌
# Created_Date: 2017.10.07
# Writer: 이윤애
#
#
# Title: 되살아나는 부동산 시장… ‘주머니 속 카드’ 또 꺼내나
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110250001
# Discription: [헤럴드경제=김성훈 기자] ‘8.2 부동산 대책’이 나온지 두 달이 다 돼 가면서 얼어붙었던 부동산 시장이 조금씩 살아나고 있다. 문재인 대통령이 “주머니 속에 있다”고 했던 추가 부동산 대책을 꺼낼지 주목된다.    한국감정원에 따르면, 지난 9월25일 기준 서울 아파트 값은 1주일 동안 0.08% 상..
# Newspaper: 헤럴드경제
# Created_Date: 2017.10.07
# Writer: 김성훈
#
#
# Title: 초과이익환수제 부활까지 석달… 논란은 계속 중
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007110147001
# Discription: -재건축 과열 잡으려 도입  -미실현 이익 과세 등 논란  -“부과시점 조절 등으로 개선해야”      [헤럴드경제=김성훈 기자] 재건축 초과이익환수제 시행이 석달 앞으로 다가왔다. 정부는 예정대로 이 제도를 시행하겠다고 공언한 상태지만,..문재인 정부는 초과이익환수제를 시행하겠다고 몇차례 확언한 바 있다.
# Newspaper: 헤럴드경제
# Created_Date: 2017.10.07
# Writer: 김성훈
#
#
# Title: 靑, 추석 막바지 北도발 가능성 예의주시… NSC 비상가동
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20171007103120001
# Discription: 청와대는 7일 북한이 추석연휴 막바지인 오는 10일 노동당 창건일을 전후해 미사일 등을 이용한 추가 도발 가능성이 있다고 보고 상황을 예의주시하고 있는 것으로 알려졌다. 청와..이와 관련해 정의용 청와대 국가안보실장은 지난 달 27일 청와대 상춘재에서 열린 문재인 대통령과 여야 4당 대표와의 만찬 회동에서
# Newspaper: 서울신문
# Created_Date: 2017.10.07
# Writer: 문경근
#
#
# Title: 靑, 北 추가 도발 예의주시..."도발 징후는 아직"
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007103003002
# Discription: 청와대는 오는 10일, 노동당 창건일을 전후로 북한이 추가 도발할 가능성이 있다고 보고 상황을 예의주시하고 있습니다.  청와대 관계자는 아..앞서 정의용 국가안보실장은 지난달 27일, 문재인 대통령과 여야 4당 대표 만찬 회동에서 10월 10일이나 18일을 전후해 북한의 추가 도발이 예상된다고 보고했습니다.
# Newspaper: YTN
# Created_Date: 2017.10.07
# Writer: None
#
#
# Title: 치매, 노화와는 다르다…치매국가책임제 활용법
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007102836001
# Discription: 올해 70살인 남성 장순원(가명)씨는 최근 조금 전 들은 이야기를 기억하지 못하는 일이 잦아졌다. 술자리가 끊이지 않았던 회사를 그만두고 시작한 사업은 스트레스가 많았다.. 정부는 문재인 대통령의 공약인 치매국가책임제를 실현하기 위해 오는 12월부터 전국 252곳 보건소에 치매안심센터를 설치하겠다고 밝혔다.
# Newspaper: 한겨레
# Created_Date: 2017.10.07
# Writer: None
#
#
# Title: 靑 관람객 증가...지금 신청해도 내년 2월 가능
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007102802001
# Discription: 문재인 정부 출범 후 시민들의 청와대 관람 신청이 크게 늘어 지금 신청해도 내년 2월에야 볼 수 있는 것으로 나타났습니다.  청와대 경내는 매주 화요일부터 금요일, 둘째·넷째 주 토요일에 관람할 수 있는..문재인 정부가 출범한 5월부터 9월까지는 월평균 2만2천백여 명으로 관람객 수가 3.35배 늘었습니다.
# Newspaper: YTN
# Created_Date: 2017.10.07
# Writer: None
#
#
# Title: ‘적폐청산’이라는데 왜 자꾸 ‘정치보복’ 논란이 일어날까
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007101817001
# Discription:  따라서 이 부분은 문재인 대통령도 어떻게 해 볼 도리가 없습니다.  이 대목에서 문재인 대통령과 청와대 참모들의 지혜가 필요합니다. 문재인 대통령에게 실제로 이상주의자의 면모가 있는 것은 사실입니다...문재인 대통령이 이상주의자라는 진단에 저는.. 문재인 대통령은 대선 직후 노무현 전 대통령 추도식에 참석해
# Newspaper: 한겨레
# Created_Date: 2017.10.07
# Writer: None
#
#
# Title: 정미홍 수위 높은 발언 계속…"관종? 관심받는 거 싫어해"
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20171007101058001
# Discription: 문재인 대통령 부인 김정숙 여사를 공개적으로 비난해 논란의 중심에 선 KBS 아나운서 출신 정미홍이 계속해 수위 높은 발언을 이어가고 있다.    지난 1일 정미홍은 자신의 페이스북에 김정숙 여사를 향해 "사치부릴 시간에 영어 공부나 좀 하고, 운동해서 살이나 좀 빼시길"이라는 글을 남겼다.    해당 ..
# Newspaper: 세계일보
# Created_Date: 2017.10.07
# Writer: 한누리
#
#
# Title: ‘홍준표 키즈’는 태풍일까 미풍일까
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007100854001
# Discription: ‘홍준표 키즈’는 내년 지방선거에서 과연 ....문재인 대통령의 고향인 경남은 두 거대정당의 절대 물러설 수 없는 전쟁터가 될 것이 분명하다. ‘문재인 대통령의 복심’으로 통하는 민주당 김경수(51·김해을) 의원의 경남도지사 선거 출마 필요성이 제기되고 있는데, 김 의원 본인은 명확한 뜻을 밝히지 않고 있다.
# Newspaper: 한겨레
# Created_Date: 2017.10.07
# Writer: 최상원
#
#
# Title: 청와대 관람신청 폭증…내년 2월에나 갈 수 있다
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20171007100752001
# Discription: 문재인 대통령 트위터 캡처.  지금 당장 신청해도 내년 2월에나 관람할 수 있을 만큼 청와대 관람을 원하는 사람이 많은 것으로 나타났다.    7일 청와대에 따르면 새 정부가 출범한 지난 5월부터 9월까지 월평균 청와대 관람객 수는 2만2000여명이다.    박근혜 전 대통령 탄핵 기간을 포함한 올 1월..
# Newspaper: 세계일보
# Created_Date: 2017.10.07
# Writer: 김동환
#
#
# Title: '정권 초반 지방선거는 여당 승리' 공식, 내년에도 통할까
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100601.20171007100125001
# Discription: 제7회 지방선거(2018년 6월13일)가 8개월 앞으로 다가왔다. 이번 지방선거는 시 ·도지사 등 풀뿌리 권력을 선출한다는 의미 외에 문재인 정부 출범 후  처음 치러지는 전국 단위 선거라는 점에서 정치적 의미가 크다. 여당이 승리하 면 문재인 정부는 국정 운영에 더욱 가속도를 낼 수 있다. 반면 야당이..
# Newspaper: 한국경제
# Created_Date: 2017.10.07
# Writer: None
#
#
# Title: ‘쉬운 해고’ 지침 폐기는 정부의 시장 개입일까
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007095833002
# Discription: 경제학자들의 눈길을 빠르게 사로잡는 단어를 꼽으라면 ‘시장 개입’입니다. 균형이라는 개념을 통해서 세상을 바라보는 경제학자들은 외부적 개입에 즉각적으.. 박근혜 정부의 창조경제에 대해서 할 말이 없던 학자들이 문재인 정부의 경제정책에 대해서는 칼럼을 쓰기 시작하고, 현실 참여적 연구자로 거듭날 이유입니다.
# Newspaper: 한겨레
# Created_Date: 2017.10.07
# Writer: None
#
#
# Title: 靑, 추석 막바지 北도발 가능성 예의주시…“아직 징후 포착안돼”
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20171007095423001
# Discription: [헤럴드경제] 청와대는 북한이 10일 노동당 창건일을 전후해 추가 도발 가능성이 있다고 보고, 상황을 예의주시하고 있다. 정의용 청와대 국가안보실장은 지난 달 27일 청와대 상춘재에서 열린 문재인 대통령과 여야 4당 대표와의 만찬 회동에서 “10월 10일 혹은 18일을 전후로 북한의 추가도발이 예상된다”..
# Newspaper: 헤럴드경제
# Created_Date: 2017.10.07
# Writer: 박병국
#
#
# Title: 심블리 심상정, 리베로 노회찬, 꿈나무 이정미의 소명
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01101001.20171007094809001
# Discription:  안경환·조대엽·박성진 등 문재인 정부 장관 후보자들의 낙마를 주장했고 실현됐다는 점에서 ..문재인 후보와 박빙의 승부를 펼친 것이다. 노회찬 원내대표는 문재인 정권과의 적절한 관계 설정도 고민하고 있다...문재인 정부를 더..‘촛불정권’을 표방하는 문재인 정부에서 정의당의 활로를 찾기 위한 나름의 고민인 셈이다.
# Newspaper: 한겨레
# Created_Date: 2017.10.07
# Writer: 김태규
#
#
# Title: 미리 보는 호찌민-경주 세계문화엑스포
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=08100401.20171007094602001
# Discription: [앵커] 오는 11월 베트남에서는 '호찌민-경주세계문화엑스포'가 열립니다.  캄보디아 앙코르와트, 터키 이스탄불에 이어 해외에서 열리는 세 번째 경주 엑스포인데요.  23일 동안 우리 문화를 알리는 수준 높고 다..문재인 대통령을 비롯한 해외 각국 주요 인사들이 개막식에 참석하기를 내심 기대하고 있습니다.
# Newspaper: YTN
# Created_Date: 2017.10.07
# Writer: None
#
#
# Title: 靑관람 대기줄 '끝이 안 보여'…지금 신청해도 내년 2월 가능
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01200201.20171007091854001
# Discription: 문재인 정부 출범 이후 청와대 관람 신청이 크게 늘어나 지금 당장 신청해도 사실상 내년 2월에야 청와대 관람을 할 수 있는 것으로 나타났다.  청와대에 따르면 새 정부가 출범한 5월부터 9월까지(8월은 혹서기 휴관으로 제외) 월평균 청와대 관람객 수는 2만2천118명에 달했다.  반면, 박근혜 전 대통령..
# Newspaper: 경인일보
# Created_Date: 2017.10.07
# Writer: 박주우

# %% [markdown]
# ### 여러 페이지 적용 및 함수 구현

# %%
from collections import OrderedDict
from itertools import count
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup


def make_scraped_data(keyword, max_page=None): 
    scraped_data = {}
    
#     for page in count(1):
    for page in range(1, 7):
        lines = '''listPage:{}
listCount:10
keyword:{}
orderByOption:desc
fromDate:
toDate:
provider_code:
provider_name:
category_code:
category_name:
larm_incident_category_path:
larm_incident_category_nm:
search_field:_search
search_method:0
realKeyword:
keywordType:N
byline:'''.format(page, keyword).splitlines()

        data = {}
        for line in lines:
            key, value = line.split(':', 1)
            if value == 'null':
                value = None
            data[key] = value

        result_url = 'http://211.43.216.33/search/totalSearchList.do'
        r = requests.post(result_url, data=data)
        print(str(page) + ' page', r)
        soup = BeautifulSoup(r.text, 'html.parser')

        article_list = soup.select('.list div')

        for article in article_list:
            items = OrderedDict()
            items['title'] = article.select_one('dt a').text.strip()
            items['link'] = urljoin(result_url, article.select_one('dt a')['href'])
            items['discription'] = article.select_one('dd a').text

            made = article.select_one('.txt_blue11').text.strip().split()

            items['newspaper'] = made[0]
            items['created_date'] = made[2]
            try:
                items['writer'] = made[4]
            except IndexError:
                items['writer'] = None

            # 멤버십 체크
            if items['link'] in scraped_data:
                return scraped_data
            scraped_data[items['link']] = items
        
        # max_page
        if max_page:
            if page >= max_page:
                break

    return scraped_data

# %% [markdown]
# ### <font color='red'>FIXME : 4page까지만 나오고 끝나야 하는데.. 멤버십 체크가 안 먹음!</font>

# %%
result = make_scraped_data(keyword='후덜덜')
# Out:
# 1 page <Response [200]>
# 2 page <Response [200]>
# 3 page <Response [200]>
# 4 page <Response [200]>
# 5 page <Response [200]>
# 6 page <Response [200]>

# %%
len(result)
# Out:
# 27

# %%
result
# Out:
# {'http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20170708033918001': OrderedDict([('title',
#                '후덜덜'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20170708033918001'),
#               ('discription',
#                '7일 경기 광명 광명동굴에 설치된 이색 공포체험관 ‘좀비 캐슬’ 사전 체험 행사를 찾은 체험객들이 괴물 복장을 한 연기자들을 보고 놀라고 있다. 좀비 캐슬은 8일부터 정식 운영에 들어간다. 연합뉴스'),
#               ('newspaper', '서울신문'),
#               ('created_date', '2017.07.08'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.2013112810012829656': OrderedDict([('title',
#                '클라라, 무보정 직찍…재킷 안 몸매 후덜덜'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.2013112810012829656'),
#               ('discription',
#                '배우 클라라의 화보 촬영 비하인드컷이 공개됐다.\xa0    명품 몸매와 섹시한 외모로 주목받고 있는 클라라는 스포츠 브랜드 스케쳐스 화보에서 후드 티셔츠와 핫팬츠, 다운재킷으로 이미지 변신에 성공했다.\xa0    클라라는 공개된 사진에서 숨겨둔 반전 매력을 드러내기도 했다. 무보정 사진임에도 굴욕없는 몸매를 자..'),
#               ('newspaper', '세계일보'),
#               ('created_date', '2013.11.28'),
#               ('writer', '정은나리')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20150630100000880': OrderedDict([('title',
#                '소녀시대 컴백 수영, 글로벌 스타다운 화사한 미모에 섹시한 각선미 ‘..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20150630100000880'),
#               ('discription',
#                '소녀시대 컴백 수영소녀시대 컴백 수영, 글로벌 스타다운 화사한 미모에 섹시한 각선미 ‘완벽해’\xa0소녀시대 컴백 소식에 화제인 가운데 과거 수영의 모습이 눈길을 끌고 있다.\xa0과거 수영은 한국 대표로 뉴욕 모던 럭셔리 브랜드 코치(COACH)의 2015 Fall 컬렉..“소녀시대 컴백 수영, 몸매 진짜 후덜덜” '),
#               ('newspaper', '세계일보'),
#               ('created_date', '2015.06.30'),
#               ('writer', '박현주')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.2015063010017760655': OrderedDict([('title',
#                '소녀시대 컴백 수영, 글로벌 스타다운 화사한 미모에 섹시한 각선미 ‘..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.2015063010017760655'),
#               ('discription',
#                '소녀시대 컴백 수영  소녀시대 컴백 수영, 글로벌 스타다운 화사한 미모에 섹시한 각선미 ‘완벽해’\xa0소녀시대 컴백 소식에 화제인 가운데 과거 수영의 모습이 눈길을 끌고 있다.\xa0과거 수영은 한국 대표로 뉴욕 모던 럭셔리 브랜드 코치(COACH)의 2015 Fall ..“소녀시대 컴백 수영, 몸매 진짜 후덜덜” '),
#               ('newspaper', '세계일보'),
#               ('created_date', '2015.06.30'),
#               ('writer', '인터넷팀')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20150827100000268': OrderedDict([('title',
#                "이선정, 과거 '남자셋 여자셋' 함께 출연한 연예인들 보니..'후덜덜'"),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20150827100000268'),
#               ('discription',
#                "이선정, 과거 `남자셋 여자셋` 함께 출연한 연예인들 보니..`후덜덜`이선정, 과거 '남자셋 여자셋' 함께 출연한 연예인들 보니..'후덜덜'지난 26일 방송된 JTBC '투유 프로젝트-슈가맨을 찾아서'에서는 유재석 팀과 유희열 팀이 두 번째 대결을 펼치는 모습이 그려진 가운데 유희열 팀으로 이선정이 출연.."),
#               ('newspaper', '세계일보'),
#               ('created_date', '2015.08.27'),
#               ('writer', '박현주')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20160108001121362': OrderedDict([('title',
#                '빈지노 여자친구, 스테파니 미초바, 민망한 옷차림…우월한 다리 길이 ..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20160108001121362'),
#               ('discription',
#                "빈지노 여자친구, 스테파니 미초바, 민망한 옷차림…우월한 다리 길이 `시선강탈` (사진= 스테파니 미초바 SNS)빈지노 여자친구, 스테파니 미초바, 민망한 옷차림…우월한 다리 길이 '시선강탈'     스테파니 미초바 사진이 화제다.     랩퍼 빈지노의 여자친구이자 ..′후덜덜′한 다리길이를 자랑하고 있다."),
#               ('newspaper', '세계일보'),
#               ('created_date', '2015.09.22'),
#               ('writer', '이슈팀')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20160108011304444': OrderedDict([('title',
#                '‘동상이몽’ 유재석, 충격적 비주얼 ‘안경 벗은 이유는?’'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20160108011304444'),
#               ('discription',
#                '‘동상이몽’에서 유재석이 안경 벗은 ‘쌩얼’을 공개해 화제다. \xa0 지난 10일 방송된 SBS 예능 ‘동상이몽, 괜찮아 괜찮아!(이하 동상이몽)’에서 유재석은 출연자를 웃겨달라는 김구라의 말에 안경을 벗어던지며 맨 얼굴을 공개했다. \xa0 이날 방송은 매일같이 집밖으로 뛰쳐나가..“동상이몽 유재석 쌩얼 후덜덜” '),
#               ('newspaper', '세계일보'),
#               ('created_date', '2015.10.11'),
#               ('writer', '이린')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01400351.2013070310011524248': OrderedDict([('title',
#                '공민지 헬스장 포착, 뒤태만으로 후덜덜'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01400351.2013070310011524248'),
#               ('discription',
#                '[대전=중도일보] 공민지 헬스장 포착   그룹 투애니원의 멤버 공민지가 헬스장에 포착됐다.  2일 공민지는 자신의 트위터에 “Morning stretching”이라는 글과 함께 사진을 올렸다.  공개된 사진 속에는 공민지가 헬스장에서 스트레칭을 하고 있다. 특히 공민지는 운동복 차림에도 불구 굴욕없는 뒤..'),
#               ('newspaper', '중도일보'),
#               ('created_date', '2013.07.03'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01500051.20160428220019243': OrderedDict([('title',
#                '겁없는 소지섭도 절벽신 찍으며 후덜덜'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01500051.20160428220019243'),
#               ('discription',
#                '겁없는 소지섭도 절벽신 찍으며 후덜덜    MBC TV 수목드라마 ‘로드 넘버원’ 출연배우들 고생담 털어놔         MBC 드라마 ‘로드 넘버원’ 출연배우 소지섭(왼쪽부터), 김하늘, 윤계상, 최민수.뉴시스   MBC TV 수목드라마 ‘로드 넘버원’이 23일 밤 9시55분에 첫 방송된다.  출연배우..'),
#               ('newspaper', '경남신문'),
#               ('created_date', '2010.06.22'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=01500701.2013011110010023684': OrderedDict([('title',
#                "순금 소총 발견 겉면이 온통 '번쩍번쩍' 가격이 무려 5천300만 원"),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=01500701.2013011110010023684'),
#               ('discription',
#                "순금 소총 발견최근 한 온라인 커뮤니티 게시판에 '순금으로 만들어진 소총' 사진이 올라와 누리꾼들의 관심을 끌었다.사진 속 순금 소총은 온두라스에서 발견된 것으로 기종은 AK-47이다. 겉면이 모두 순금으로 도금돼 있는 이 소총의 가격은 5만 달러로 우리 돈으로는 5천..'순금 소총 발견, 가격이 후덜덜' "),
#               ('newspaper', '부산일보'),
#               ('created_date', '2013.01.11'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20151130014018001': OrderedDict([('title',
#                '한양대학교 입학처 화제, 하석진 ‘한양대 공대 오빠’ 스펙 보니 ‘후..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20151130014018001'),
#               ('discription',
#                "한양대학교 입학처 화제, 하석진 ‘한양대 공대 오빠’ 스펙 보니 ‘후덜덜’[김조근 기자] 한양대학교 입학처와 더불어 한양대 기계공학과 출신 하석진의 성적이 화제다. 하석진은 과거 방송된 케이블TV tvN 예능프로그램 '명단공개 2015' 속 '의외의 반전 학벌 스타'의 명단에 이름을 올렸다.  하석진은 .."),
#               ('newspaper', '매일경제'),
#               ('created_date', '2015.11.30'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129133930674': OrderedDict([('title',
#                '장동민 나비 열애설 부인, 몸매가 얼마나 대단하길래 장동민과 열애설까..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129133930674'),
#               ('discription',
#                '장동민 나비 열애설 부인, 몸매가 얼마나 대단하길래 장동민과 열애설까지? ‘황홀’  장동민 나비 열애설 부인, 친한 선후배라고?  장동민 나비 열애설 부인에 나비의 황홀한 몸매가 수면 위로 떠올랐다.   18일 한 매체는 "개그맨 장동민이 여가수 나..“장동민 나비 열애설 부인, 몸매가 저 정도면 후덜덜” '),
#               ('newspaper', '매일경제'),
#               ('created_date', '2015.03.19'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129133938189': OrderedDict([('title',
#                '장동민 나비 열애설 부인 소식에 과거 화보까지 화제…이런 모습이 있었..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129133938189'),
#               ('discription',
#                '장동민 나비 열애설 부인, 몸매가 얼마나 대단하길래 장동민과 열애설까지? ‘황홀’  장동민 나비 열애설 부인, 친한 선후배라고?  장동민 나비 열애설 부인에 나비의 황홀한 몸매가 수면 위로 떠올랐다.   18일 한 매체는 "개그맨 장동민이 여가수 나..“장동민 나비 열애설 부인, 몸매가 저 정도면 후덜덜” '),
#               ('newspaper', '매일경제'),
#               ('created_date', '2015.03.19'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129133938846': OrderedDict([('title',
#                '장동민 나비 열애설 부인 소식에 과거 섹시 화보까지 주목…아찔한 가슴..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129133938846'),
#               ('discription',
#                '장동민 나비 열애설 부인, 몸매가 얼마나 대단하길래 장동민과 열애설까지? ‘황홀’  장동민 나비 열애설 부인, 친한 선후배라고?  장동민 나비 열애설 부인에 나비의 황홀한 몸매가 수면 위로 떠올랐다.   18일 한 매체는 "개그맨 장동민이 여가수 나..“장동민 나비 열애설 부인, 몸매가 저 정도면 후덜덜” '),
#               ('newspaper', '매일경제'),
#               ('created_date', '2015.03.19'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129134053886': OrderedDict([('title',
#                '장동민 나비 열애설 부인, 나비 섹시화보 덩달아 화제…‘완벽 몸매’'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129134053886'),
#               ('discription',
#                '장동민 나비 열애설 부인에 나비의 황홀한 몸매가 수면 위로 떠올랐다.  지난 18일 한 매체는 "개그맨 장동민이 여가수 나비와 올해 초부터 교제 중"이라고 보도했다. 하지만 장동민과 나비 측 관계자는 다른 매체를 통해 "두 사람은 친한 오빠와 동생 ..“장동민 나비 열애설 부인, 몸매가 저 정도면 후덜덜” '),
#               ('newspaper', '매일경제'),
#               ('created_date', '2015.03.19'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20170620134519001': OrderedDict([('title',
#                '‘싸이 흠뻑쇼’, "겨터파크 준비하고 오세요~"'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20170620134519001'),
#               ('discription',
#                "[매일경제 스타투데이 이은솔 인턴기자] 가수 싸이가 5년만에 여름콘서트 ‘싸이 흠뻑쇼’를 개최하는 가운데, 지난 ‘싸이 흠뻑쇼’ 콘서트 후기가 눈길을 끈다. 20일 정오 ‘싸이 흠뻑쇼-서머 스웨그'(SUMMER SWAG)’는 인터파크 티켓을 통해 예매가 시작됐다. ..“밤 샐 때까지 공연합니다..후덜덜”, "),
#               ('newspaper', '매일경제'),
#               ('created_date', '2017.06.20'),
#               ('writer', '이은솔')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20170906103044001': OrderedDict([('title',
#                'KEB하나은행-SKT 합작 앱 ‘핀크(finnq)’ 출시에 은행원들 ..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20170906103044001'),
#               ('discription',
#                '하나금융그룹이 국내 1위 이통사 SK텔레콤과 손잡고 새로운 플랫폼 앱 핀크(Finnq)을 내놨는데. 핀크는 신용카드 거래 내역을 기반으로 한 지출(소비)관리 서비스 앱. 하나은행 계좌 개설 외에 예·적금 등 여러 금융상품에 가입할 수 있고 타 은행 상품 가입, 비교도 가능. 특히 인터넷전문은행을 경쟁 상..'),
#               ('newspaper', '매일경제'),
#               ('created_date', '2017.09.06'),
#               ('writer', '박수호')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20170313125641001': OrderedDict([('title',
#                '‘보이스’ 마지막회 의사는 누구? 김재욱 인생캐릭터 ‘살인마를 살해한..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20170313125641001'),
#               ('discription',
#                '‘보이스’ 마지막회 의사는 누구? 김재욱 인생캐릭터 ‘살인마를 살해한 김권’ 후덜덜    드라마 ‘보이스’ 마지막회에서 김권이 범인 김재욱을 죽이는 역할을 연기하며 강인한 인상을 전했다.    지난 12일 12일 방송한 OCN ‘‘보이스’’ 마지막회에서 김권은 살인마 모태구(김재욱)를 살해한 의사로 등장..'),
#               ('newspaper', '서울경제'),
#               ('created_date', '2017.03.13'),
#               ('writer', '박재영')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100351.20130729020742034': OrderedDict([('title',
#                '[월세 공포]“생활비도 빠듯한데 반전세월세로 바꾸라니” 세입자 후덜덜'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100351.20130729020742034'),
#               ('discription',
#                '[이투데이] 박태진 기자(tjpippo@etoday.co.kr)28일 오후 서울 신천역 부근 한 상가 건물. 이곳에 들어서 있는 20여개 공인중개사무소 출입문과 유리벽에는 매매를 비롯한 전세, 월세 물량 안내문이 다닥다닥 붙어 있었다. 부동산중개사무소 유리벽에 내걸린 물량은 적게는 50만원부터 200만원..'),
#               ('newspaper', '이투데이'),
#               ('created_date', '2013.07.29'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100601.20161110153038877': OrderedDict([('title',
#                '[뉴스래빗] "뉴스를 실험하라"…토끼뉴스 1년의 기록'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100601.20161110153038877'),
#               ('discription',
#                '"아직은 누구도 정의할 수 없지만 반드시 찾아야할 뉴스의 \'새로운 그것(it)\'을 만나고자 합니다. 토끼(래빗)처럼 독자를 향해 \'쫑긋\' 귀를 세우겠다는 저희의 약.. 좋아요, 기쁨, 좌절, 여유, 슬픔, 당황, 분노, 의심, 사랑스러움, 못마땅함, 추천, 후덜덜 등 뉴스래빗 캐릭터를 형상화한 24종입니다.'),
#               ('newspaper', '한국경제'),
#               ('created_date', '2016.11.10'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20160116020247856': OrderedDict([('title',
#                '냉장고 문 닫아라 “안 닫으면 한 대 맞을듯”'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20160116020247856'),
#               ('discription',
#                '‘냉장고 문 닫아라’ 사진이 화제가 되고 있다.    최근 온라인 커뮤니티에 올라온 이 사진은 냉장고 속에서 사람 얼굴 표정을 한 우유통의 모습을 담고 있다. 해당 플라스틱 우유통의 찌그러진 굴곡과 튀어나온 손잡이는 마치 사람의 눈, 코, 입처럼 보인다. 특히 이 표정은 험상궂은 인상으로 “냉..“후덜덜” '),
#               ('newspaper', '헤럴드경제'),
#               ('created_date', '2012.04.03'),
#               ('writer', '김지윤')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20140716080847001': OrderedDict([('title',
#                '터널 3d 웹툰, 마우스를 서서히 내리는 순간 “귀신이 모니터로” 후..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20140716080847001'),
#               ('discription',
#                '\xa0 ▲\xa0터널 3d 웹툰© 브레이크뉴스 터널 3d 웹툰, 마우스를 서서히 내리는 순간 “귀신이 모니터로” 후덜덜 터널 3d 웹툰 ‘핫핫핫’ 보고 또 보는 이유는?   터널 3d 웹툰이 그야말로 화제다. 터널 3d 웹툰은 이 때문에 주요 포털 화제의 검색어로 등극하는 기염을 토하고 있다.  \xa0  터널 3d ..'),
#               ('newspaper', '브레이크뉴스'),
#               ('created_date', '2014.07.16'),
#               ('writer', '이선정')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20141007090726001': OrderedDict([('title',
#                '진재영 연매출 200억 이뤄낸 쇼핑몰 사진 ‘온라인 강타’...“국보..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20141007090726001'),
#               ('discription',
#                '\xa0 © 브레이크뉴스 진재영 연매출 200억, 필라테스 시범으로 환상 몸매 진재영 연매출 200억 속엔 환상적 몸매도 한 몫?  \xa0  진재영 연매출 200억 ‘키워드’  \xa0  진재영 연매출 200억이 그야말로 연예가의 빅뉴스로 자리잡았다. 진재영 연매출 2..“진재영 연매출 200억, 몸매가 저러니 후덜덜” '),
#               ('newspaper', '브레이크뉴스'),
#               ('created_date', '2014.10.07'),
#               ('writer', '이선정')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20141117094142002': OrderedDict([('title',
#                '웹드라마 인형의 집, 소녀에게 무슨 일? ‘역대급 공포물’에 정희철 ..'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20141117094142002'),
#               ('discription',
#                '\xa0 © 브레이크뉴스 웹드라마 인형의 집, 일상 속 극한의 공포 담았다, 인형은 누구? 웹드라마 인형의 집 ‘키워드’ 등극  \xa0  웹드라마 인형의 집이 화제다. 웹드라마 인형의 집은 이 때문에 주요 포털 화제의 검색어로 등극했다.  \xa0  웹드라마 인형의 집이 이처럼 빅이슈인 ..“웹드라마 인형의 집 후덜덜” '),
#               ('newspaper', '브레이크뉴스'),
#               ('created_date', '2014.11.17'),
#               ('writer', '이선정')]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20160309212906252': OrderedDict([('title',
#                '곽희성 다솜, 훈남 외모+근육질 몸매 ‘후덜덜’..어디서 봤더라?'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20160309212906252'),
#               ('discription',
#                '실시간 검색어 1위에 올라 씨스타 다솜에게 감사 인사 전해 눈길 이민경 기자 brnstar@naver.com     ▲ 곽희성 다솜 감사인사 <사진출처=곽희성 트위터> ⓒ 브레이크뉴스    브레이크뉴스 이민경 기자= 곽희성이 씨스타 다솜에게 감사 인사를 전했다.   배우 곽희성은 28일 자신의 트위터에 '),
#               ('newspaper', '브레이크뉴스'),
#               ('created_date', '2014.01.28'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=07100902.20160614183051470': OrderedDict([('title',
#                '케이블카'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=07100902.20160614183051470'),
#               ('discription',
#                '춘천시 삼육 초등학교 3학년 사랑반 한승우  케이블카  올라갈 때에는 후덜덜  무서웠는데  내려올 때에는 휴우우 괜한 걱정'),
#               ('newspaper', '어린이강원'),
#               ('created_date', '2016.04.13'),
#               ('writer', None)]),
#  'http://211.43.216.33/search/totalSearchView.do?news_id=07100902.20160614183057438': OrderedDict([('title',
#                '케이블카'),
#               ('link',
#                'http://211.43.216.33/search/totalSearchView.do?news_id=07100902.20160614183057438'),
#               ('discription',
#                '춘천시 삼육 초등학교 3학년 사랑반 안상운  케이블카  올라갈 때에는 후덜덜  무서웠는데  내려올 때에는 휴우우 괜한 걱정'),
#               ('newspaper', '어린이강원'),
#               ('created_date', '2016.04.14'),
#               ('writer', None)])}

# %%
for key, value_dict in result.items():
    for key, value in value_dict.items():
        print(key.title() + ': ' + str(value))
    print('\n')
# Out:
# Title: KEB하나은행-SKT 합작 앱 ‘핀크(finnq)’ 출시에 은행원들 ..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20170906103044001
# Discription: 하나금융그룹이 국내 1위 이통사 SK텔레콤과 손잡고 새로운 플랫폼 앱 핀크(Finnq)을 내놨는데. 핀크는 신용카드 거래 내역을 기반으로 한 지출(소비)관리 서비스 앱. 하나은행 계좌 개설 외에 예·적금 등 여러 금융상품에 가입할 수 있고 타 은행 상품 가입, 비교도 가능. 특히 인터넷전문은행을 경쟁 상..
# Newspaper: 매일경제
# Created_Date: 2017.09.06
# Writer: 박수호
#
#
# Title: 후덜덜
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100611.20170708033918001
# Discription: 7일 경기 광명 광명동굴에 설치된 이색 공포체험관 ‘좀비 캐슬’ 사전 체험 행사를 찾은 체험객들이 괴물 복장을 한 연기자들을 보고 놀라고 있다. 좀비 캐슬은 8일부터 정식 운영에 들어간다. 연합뉴스
# Newspaper: 서울신문
# Created_Date: 2017.07.08
# Writer: None
#
#
# Title: ‘싸이 흠뻑쇼’, "겨터파크 준비하고 오세요~"
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20170620134519001
# Discription: [매일경제 스타투데이 이은솔 인턴기자] 가수 싸이가 5년만에 여름콘서트 ‘싸이 흠뻑쇼’를 개최하는 가운데, 지난 ‘싸이 흠뻑쇼’ 콘서트 후기가 눈길을 끈다. 20일 정오 ‘싸이 흠뻑쇼-서머 스웨그'(SUMMER SWAG)’는 인터파크 티켓을 통해 예매가 시작됐다. ..“밤 샐 때까지 공연합니다..후덜덜”,
# Newspaper: 매일경제
# Created_Date: 2017.06.20
# Writer: 이은솔
#
#
# Title: ‘보이스’ 마지막회 의사는 누구? 김재욱 인생캐릭터 ‘살인마를 살해한..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100311.20170313125641001
# Discription: ‘보이스’ 마지막회 의사는 누구? 김재욱 인생캐릭터 ‘살인마를 살해한 김권’ 후덜덜    드라마 ‘보이스’ 마지막회에서 김권이 범인 김재욱을 죽이는 역할을 연기하며 강인한 인상을 전했다.    지난 12일 12일 방송한 OCN ‘‘보이스’’ 마지막회에서 김권은 살인마 모태구(김재욱)를 살해한 의사로 등장..
# Newspaper: 서울경제
# Created_Date: 2017.03.13
# Writer: 박재영
#
#
# Title: [뉴스래빗] "뉴스를 실험하라"…토끼뉴스 1년의 기록
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100601.20161110153038877
# Discription: "아직은 누구도 정의할 수 없지만 반드시 찾아야할 뉴스의 '새로운 그것(it)'을 만나고자 합니다. 토끼(래빗)처럼 독자를 향해 '쫑긋' 귀를 세우겠다는 저희의 약.. 좋아요, 기쁨, 좌절, 여유, 슬픔, 당황, 분노, 의심, 사랑스러움, 못마땅함, 추천, 후덜덜 등 뉴스래빗 캐릭터를 형상화한 24종입니다.
# Newspaper: 한국경제
# Created_Date: 2016.11.10
# Writer: None
#
#
# Title: 케이블카
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=07100902.20160614183057438
# Discription: 춘천시 삼육 초등학교 3학년 사랑반 안상운  케이블카  올라갈 때에는 후덜덜  무서웠는데  내려올 때에는 휴우우 괜한 걱정
# Newspaper: 어린이강원
# Created_Date: 2016.04.14
# Writer: None
#
#
# Title: 케이블카
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=07100902.20160614183051470
# Discription: 춘천시 삼육 초등학교 3학년 사랑반 한승우  케이블카  올라갈 때에는 후덜덜  무서웠는데  내려올 때에는 휴우우 괜한 걱정
# Newspaper: 어린이강원
# Created_Date: 2016.04.13
# Writer: None
#
#
# Title: 한양대학교 입학처 화제, 하석진 ‘한양대 공대 오빠’ 스펙 보니 ‘후..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20151130014018001
# Discription: 한양대학교 입학처 화제, 하석진 ‘한양대 공대 오빠’ 스펙 보니 ‘후덜덜’[김조근 기자] 한양대학교 입학처와 더불어 한양대 기계공학과 출신 하석진의 성적이 화제다. 하석진은 과거 방송된 케이블TV tvN 예능프로그램 '명단공개 2015' 속 '의외의 반전 학벌 스타'의 명단에 이름을 올렸다.  하석진은 ..
# Newspaper: 매일경제
# Created_Date: 2015.11.30
# Writer: None
#
#
# Title: ‘동상이몽’ 유재석, 충격적 비주얼 ‘안경 벗은 이유는?’
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20160108011304444
# Discription: ‘동상이몽’에서 유재석이 안경 벗은 ‘쌩얼’을 공개해 화제다.   지난 10일 방송된 SBS 예능 ‘동상이몽, 괜찮아 괜찮아!(이하 동상이몽)’에서 유재석은 출연자를 웃겨달라는 김구라의 말에 안경을 벗어던지며 맨 얼굴을 공개했다.   이날 방송은 매일같이 집밖으로 뛰쳐나가..“동상이몽 유재석 쌩얼 후덜덜”
# Newspaper: 세계일보
# Created_Date: 2015.10.11
# Writer: 이린
#
#
# Title: 빈지노 여자친구, 스테파니 미초바, 민망한 옷차림…우월한 다리 길이 ..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20160108001121362
# Discription: 빈지노 여자친구, 스테파니 미초바, 민망한 옷차림…우월한 다리 길이 `시선강탈` (사진= 스테파니 미초바 SNS)빈지노 여자친구, 스테파니 미초바, 민망한 옷차림…우월한 다리 길이 '시선강탈'     스테파니 미초바 사진이 화제다.     랩퍼 빈지노의 여자친구이자 ..′후덜덜′한 다리길이를 자랑하고 있다.
# Newspaper: 세계일보
# Created_Date: 2015.09.22
# Writer: 이슈팀
#
#
# Title: 이선정, 과거 '남자셋 여자셋' 함께 출연한 연예인들 보니..'후덜덜'
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20150827100000268
# Discription: 이선정, 과거 `남자셋 여자셋` 함께 출연한 연예인들 보니..`후덜덜`이선정, 과거 '남자셋 여자셋' 함께 출연한 연예인들 보니..'후덜덜'지난 26일 방송된 JTBC '투유 프로젝트-슈가맨을 찾아서'에서는 유재석 팀과 유희열 팀이 두 번째 대결을 펼치는 모습이 그려진 가운데 유희열 팀으로 이선정이 출연..
# Newspaper: 세계일보
# Created_Date: 2015.08.27
# Writer: 박현주
#
#
# Title: 소녀시대 컴백 수영, 글로벌 스타다운 화사한 미모에 섹시한 각선미 ‘..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100701.20150630100000880
# Discription: 소녀시대 컴백 수영소녀시대 컴백 수영, 글로벌 스타다운 화사한 미모에 섹시한 각선미 ‘완벽해’ 소녀시대 컴백 소식에 화제인 가운데 과거 수영의 모습이 눈길을 끌고 있다. 과거 수영은 한국 대표로 뉴욕 모던 럭셔리 브랜드 코치(COACH)의 2015 Fall 컬렉..“소녀시대 컴백 수영, 몸매 진짜 후덜덜”
# Newspaper: 세계일보
# Created_Date: 2015.06.30
# Writer: 박현주
#
#
# Title: 소녀시대 컴백 수영, 글로벌 스타다운 화사한 미모에 섹시한 각선미 ‘..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100701.2015063010017760655
# Discription: 소녀시대 컴백 수영  소녀시대 컴백 수영, 글로벌 스타다운 화사한 미모에 섹시한 각선미 ‘완벽해’ 소녀시대 컴백 소식에 화제인 가운데 과거 수영의 모습이 눈길을 끌고 있다. 과거 수영은 한국 대표로 뉴욕 모던 럭셔리 브랜드 코치(COACH)의 2015 Fall ..“소녀시대 컴백 수영, 몸매 진짜 후덜덜”
# Newspaper: 세계일보
# Created_Date: 2015.06.30
# Writer: 인터넷팀
#
#
# Title: 장동민 나비 열애설 부인, 나비 섹시화보 덩달아 화제…‘완벽 몸매’
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129134053886
# Discription: 장동민 나비 열애설 부인에 나비의 황홀한 몸매가 수면 위로 떠올랐다.  지난 18일 한 매체는 "개그맨 장동민이 여가수 나비와 올해 초부터 교제 중"이라고 보도했다. 하지만 장동민과 나비 측 관계자는 다른 매체를 통해 "두 사람은 친한 오빠와 동생 ..“장동민 나비 열애설 부인, 몸매가 저 정도면 후덜덜”
# Newspaper: 매일경제
# Created_Date: 2015.03.19
# Writer: None
#
#
# Title: 장동민 나비 열애설 부인 소식에 과거 섹시 화보까지 주목…아찔한 가슴..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129133938846
# Discription: 장동민 나비 열애설 부인, 몸매가 얼마나 대단하길래 장동민과 열애설까지? ‘황홀’  장동민 나비 열애설 부인, 친한 선후배라고?  장동민 나비 열애설 부인에 나비의 황홀한 몸매가 수면 위로 떠올랐다.   18일 한 매체는 "개그맨 장동민이 여가수 나..“장동민 나비 열애설 부인, 몸매가 저 정도면 후덜덜”
# Newspaper: 매일경제
# Created_Date: 2015.03.19
# Writer: None
#
#
# Title: 장동민 나비 열애설 부인 소식에 과거 화보까지 화제…이런 모습이 있었..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129133938189
# Discription: 장동민 나비 열애설 부인, 몸매가 얼마나 대단하길래 장동민과 열애설까지? ‘황홀’  장동민 나비 열애설 부인, 친한 선후배라고?  장동민 나비 열애설 부인에 나비의 황홀한 몸매가 수면 위로 떠올랐다.   18일 한 매체는 "개그맨 장동민이 여가수 나..“장동민 나비 열애설 부인, 몸매가 저 정도면 후덜덜”
# Newspaper: 매일경제
# Created_Date: 2015.03.19
# Writer: None
#
#
# Title: 장동민 나비 열애설 부인, 몸매가 얼마나 대단하길래 장동민과 열애설까..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100101.20160129133930674
# Discription: 장동민 나비 열애설 부인, 몸매가 얼마나 대단하길래 장동민과 열애설까지? ‘황홀’  장동민 나비 열애설 부인, 친한 선후배라고?  장동민 나비 열애설 부인에 나비의 황홀한 몸매가 수면 위로 떠올랐다.   18일 한 매체는 "개그맨 장동민이 여가수 나..“장동민 나비 열애설 부인, 몸매가 저 정도면 후덜덜”
# Newspaper: 매일경제
# Created_Date: 2015.03.19
# Writer: None
#
#
# Title: 웹드라마 인형의 집, 소녀에게 무슨 일? ‘역대급 공포물’에 정희철 ..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20141117094142002
# Discription:   © 브레이크뉴스 웹드라마 인형의 집, 일상 속 극한의 공포 담았다, 인형은 누구? 웹드라마 인형의 집 ‘키워드’ 등극     웹드라마 인형의 집이 화제다. 웹드라마 인형의 집은 이 때문에 주요 포털 화제의 검색어로 등극했다.     웹드라마 인형의 집이 이처럼 빅이슈인 ..“웹드라마 인형의 집 후덜덜”
# Newspaper: 브레이크뉴스
# Created_Date: 2014.11.17
# Writer: 이선정
#
#
# Title: 진재영 연매출 200억 이뤄낸 쇼핑몰 사진 ‘온라인 강타’...“국보..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20141007090726001
# Discription:   © 브레이크뉴스 진재영 연매출 200억, 필라테스 시범으로 환상 몸매 진재영 연매출 200억 속엔 환상적 몸매도 한 몫?     진재영 연매출 200억 ‘키워드’     진재영 연매출 200억이 그야말로 연예가의 빅뉴스로 자리잡았다. 진재영 연매출 2..“진재영 연매출 200억, 몸매가 저러니 후덜덜”
# Newspaper: 브레이크뉴스
# Created_Date: 2014.10.07
# Writer: 이선정
#
#
# Title: 터널 3d 웹툰, 마우스를 서서히 내리는 순간 “귀신이 모니터로” 후..
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20140716080847001
# Discription:   ▲ 터널 3d 웹툰© 브레이크뉴스 터널 3d 웹툰, 마우스를 서서히 내리는 순간 “귀신이 모니터로” 후덜덜 터널 3d 웹툰 ‘핫핫핫’ 보고 또 보는 이유는?   터널 3d 웹툰이 그야말로 화제다. 터널 3d 웹툰은 이 때문에 주요 포털 화제의 검색어로 등극하는 기염을 토하고 있다.     터널 3d ..
# Newspaper: 브레이크뉴스
# Created_Date: 2014.07.16
# Writer: 이선정
#
#
# Title: 곽희성 다솜, 훈남 외모+근육질 몸매 ‘후덜덜’..어디서 봤더라?
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=04100608.20160309212906252
# Discription: 실시간 검색어 1위에 올라 씨스타 다솜에게 감사 인사 전해 눈길 이민경 기자 brnstar@naver.com     ▲ 곽희성 다솜 감사인사 <사진출처=곽희성 트위터> ⓒ 브레이크뉴스    브레이크뉴스 이민경 기자= 곽희성이 씨스타 다솜에게 감사 인사를 전했다.   배우 곽희성은 28일 자신의 트위터에
# Newspaper: 브레이크뉴스
# Created_Date: 2014.01.28
# Writer: None
#
#
# Title: 클라라, 무보정 직찍…재킷 안 몸매 후덜덜
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01100701.2013112810012829656
# Discription: 배우 클라라의 화보 촬영 비하인드컷이 공개됐다.     명품 몸매와 섹시한 외모로 주목받고 있는 클라라는 스포츠 브랜드 스케쳐스 화보에서 후드 티셔츠와 핫팬츠, 다운재킷으로 이미지 변신에 성공했다.     클라라는 공개된 사진에서 숨겨둔 반전 매력을 드러내기도 했다. 무보정 사진임에도 굴욕없는 몸매를 자..
# Newspaper: 세계일보
# Created_Date: 2013.11.28
# Writer: 정은나리
#
#
# Title: [월세 공포]“생활비도 빠듯한데 반전세월세로 바꾸라니” 세입자 후덜덜
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100351.20130729020742034
# Discription: [이투데이] 박태진 기자(tjpippo@etoday.co.kr)28일 오후 서울 신천역 부근 한 상가 건물. 이곳에 들어서 있는 20여개 공인중개사무소 출입문과 유리벽에는 매매를 비롯한 전세, 월세 물량 안내문이 다닥다닥 붙어 있었다. 부동산중개사무소 유리벽에 내걸린 물량은 적게는 50만원부터 200만원..
# Newspaper: 이투데이
# Created_Date: 2013.07.29
# Writer: None
#
#
# Title: 공민지 헬스장 포착, 뒤태만으로 후덜덜
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01400351.2013070310011524248
# Discription: [대전=중도일보] 공민지 헬스장 포착   그룹 투애니원의 멤버 공민지가 헬스장에 포착됐다.  2일 공민지는 자신의 트위터에 “Morning stretching”이라는 글과 함께 사진을 올렸다.  공개된 사진 속에는 공민지가 헬스장에서 스트레칭을 하고 있다. 특히 공민지는 운동복 차림에도 불구 굴욕없는 뒤..
# Newspaper: 중도일보
# Created_Date: 2013.07.03
# Writer: None
#
#
# Title: 순금 소총 발견 겉면이 온통 '번쩍번쩍' 가격이 무려 5천300만 원
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01500701.2013011110010023684
# Discription: 순금 소총 발견최근 한 온라인 커뮤니티 게시판에 '순금으로 만들어진 소총' 사진이 올라와 누리꾼들의 관심을 끌었다.사진 속 순금 소총은 온두라스에서 발견된 것으로 기종은 AK-47이다. 겉면이 모두 순금으로 도금돼 있는 이 소총의 가격은 5만 달러로 우리 돈으로는 5천..'순금 소총 발견, 가격이 후덜덜'
# Newspaper: 부산일보
# Created_Date: 2013.01.11
# Writer: None
#
#
# Title: 냉장고 문 닫아라 “안 닫으면 한 대 맞을듯”
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=02100701.20160116020247856
# Discription: ‘냉장고 문 닫아라’ 사진이 화제가 되고 있다.    최근 온라인 커뮤니티에 올라온 이 사진은 냉장고 속에서 사람 얼굴 표정을 한 우유통의 모습을 담고 있다. 해당 플라스틱 우유통의 찌그러진 굴곡과 튀어나온 손잡이는 마치 사람의 눈, 코, 입처럼 보인다. 특히 이 표정은 험상궂은 인상으로 “냉..“후덜덜”
# Newspaper: 헤럴드경제
# Created_Date: 2012.04.03
# Writer: 김지윤
#
#
# Title: 겁없는 소지섭도 절벽신 찍으며 후덜덜
# Link: http://211.43.216.33/search/totalSearchView.do?news_id=01500051.20160428220019243
# Discription: 겁없는 소지섭도 절벽신 찍으며 후덜덜    MBC TV 수목드라마 ‘로드 넘버원’ 출연배우들 고생담 털어놔         MBC 드라마 ‘로드 넘버원’ 출연배우 소지섭(왼쪽부터), 김하늘, 윤계상, 최민수.뉴시스   MBC TV 수목드라마 ‘로드 넘버원’이 23일 밤 9시55분에 첫 방송된다.  출연배우..
# Newspaper: 경남신문
# Created_Date: 2010.06.22
# Writer: None
